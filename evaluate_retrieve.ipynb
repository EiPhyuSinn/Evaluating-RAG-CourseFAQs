# %%
from elasticsearch import Elasticsearch

es_client = Elasticsearch(
    "http://localhost:9200",
    basic_auth=("elastic", "A9C4z4Pb1jo7FaM*W7uu") #docker password for elastic user
)

try:
    info = es_client.info()
    print("Connected to Elasticsearch!")
    print(info)
except Exception as e:
    print(f"Error connecting: {e}")
# Out:
# Connected to Elasticsearch!
# {'name': 'f9a115421d59', 'cluster_name': 'docker-cluster', 'cluster_uuid': '82IQaASQR2mXKzSC26s4cA', 'version': {'number': '9.2.4', 'build_flavor': 'default', 'build_type': 'docker', 'build_hash': 'dfc5c38614c29a598e132c035b66160d3d350894', 'build_date': '2026-01-08T22:07:25.170027027Z', 'build_snapshot': False, 'lucene_version': '10.3.2', 'minimum_wire_compatibility_version': '8.19.0', 'minimum_index_compatibility_version': '8.0.0'}, 'tagline': 'You Know, for Search'}

# %%
es_client.info()
# Out:
# ObjectApiResponse({'name': 'f9a115421d59', 'cluster_name': 'docker-cluster', 'cluster_uuid': '82IQaASQR2mXKzSC26s4cA', 'version': {'number': '9.2.4', 'build_flavor': 'default', 'build_type': 'docker', 'build_hash': 'dfc5c38614c29a598e132c035b66160d3d350894', 'build_date': '2026-01-08T22:07:25.170027027Z', 'build_snapshot': False, 'lucene_version': '10.3.2', 'minimum_wire_compatibility_version': '8.19.0', 'minimum_index_compatibility_version': '8.0.0'}, 'tagline': 'You Know, for Search'})

# %%
index_settings = {
    "settings": {
        "number_of_shards": 1,
        "number_of_replicas": 0
    },
    "mappings": {
        "properties": {
            "text": {"type": "text"},
            "section": {"type": "text"},
            "question": {"type": "text"},
            "course": {"type": "keyword"},
            "id": {"type": "keyword"},
        }
    }
}

index_name = "course-questions"

es_client.indices.delete(index=index_name, ignore_unavailable=True)
es_client.indices.create(index=index_name, body=index_settings)
# Out:
# ObjectApiResponse({'acknowledged': True, 'shards_acknowledged': True, 'index': 'course-questions'})

# %%
import json 
from tqdm import tqdm 

with open('/home/gwm-279/Documents/DTC_AI/artifacts/documents_with_ids.json','r') as f:
          docs = json.load(f)

for doc in tqdm(docs):
    es_client.index(index=index_name,document=doc)
# Out:
#   0%|          | 0/948 [00:00<?, ?it/s]
# 100%|██████████| 948/948 [00:04<00:00, 225.91it/s]

# %%
query = 'When is the deadline of course?' 
search_query =  {
    "size": 5,
    "query": {
        "bool": {
            "must": {
                "multi_match": {
                    "query": query,
                    "fields": ["question^3", "text", "section"],
                    "type": "best_fields"
                }
            },
            "filter": {
                "term": {
                    "course": "data-engineering-zoomcamp"
                }
            }
        }
    }
}
search_response = es_client.search(index=index_name,body=search_query)

search_response['hits']['hits'][0].get('_source')
# Out:
# {'text': "The purpose of this document is to capture frequently asked technical questions\nThe exact day and hour of the course will be 15th Jan 2024 at 17h00. The course will start with the first  “Office Hours'' live.1\nSubscribe to course public Google Calendar (it works from Desktop only).\nRegister before the course starts using this link.\nJoin the course Telegram channel with announcements.\nDon’t forget to register in DataTalks.Club's Slack and join the channel.",
#  'section': 'General course-related questions',
#  'question': 'Course - When will the course start?',
#  'course': 'data-engineering-zoomcamp',
#  'id': 'c02e79ef'}

# %%
import pandas 

gt_questions = pandas.read_csv('/home/gwm-279/Documents/DTC_AI/artifacts/ground-truth-questions.csv')

for index, row in gt_questions[:2].iterrows():
    query = row['question']
    course = row['course']
    document_id = row['document']
    search_query =  {
        "size": 5,
        "query": {
            "bool": {
                "must": {
                    "multi_match": {
                        "query": query,
                        "fields": ["question^3", "text", "section"],
                        "type": "best_fields"
                    }
                },
                "filter": {
                    "term": {
                        "course": course
                    }
                }
            }
        }
    }
    search_response = es_client.search(index=index_name,body=search_query)
    print(f"Query: {query} -> id: {document_id}")
    for hit in search_response['hits']['hits']:
        print(f"Retrieved Ids: {hit['_source']['id']}")
        print(f"Score: {hit['_score']}, Question: {hit['_source']['question']}")
    print("-----")
# Out:
# Query: When does the course begin? -> id: c02e79ef
# Retrieved Ids: c02e79ef
# Score: 30.217829, Question: Course - When will the course start?
# Retrieved Ids: 1f6520ca
# Score: 19.322718, Question: Course - What are the prerequisites for this course?
# Retrieved Ids: 7842b56a
# Score: 19.187729, Question: Course - Can I still join the course after the start date?
# Retrieved Ids: 63394d91
# Score: 18.713572, Question: Course - What can I do before the course starts?
# Retrieved Ids: a482086d
# Score: 18.713572, Question: Course - Can I follow the course after it finishes?
# -----
# Query: How can I get the course schedule? -> id: c02e79ef
# Retrieved Ids: eb56ae98
# Score: 42.350315, Question: Course - Can I get support if I take the course in the self-paced mode?
# Retrieved Ids: 63394d91
# Score: 36.130344, Question: Course - What can I do before the course starts?
# Retrieved Ids: a482086d
# Score: 36.130344, Question: Course - Can I follow the course after it finishes?
# Retrieved Ids: 7842b56a
# Score: 35.25964, Question: Course - Can I still join the course after the start date?
# Retrieved Ids: 2f19301f
# Score: 34.76632, Question: How can we contribute to the course?
# -----

# %%
import pandas 
from collections import defaultdict
elasticsearch_results = []

gt_questions = pandas.read_csv('/home/gwm-279/Documents/DTC_AI/artifacts/ground-truth-questions.csv')

for index, row in tqdm(gt_questions.iterrows(), total=len(gt_questions)):
    query = row['question']
    course = row['course']
    document_id = row['document']
    search_query =  {
        "size": 5,
        "query": {
            "bool": {
                "must": {
                    "multi_match": {
                        "query": query,
                        "fields": ["question^3", "text", "section"],
                        "type": "best_fields"
                    }
                },
                "filter": {
                    "term": {
                        "course": course
                    }
                }
            }
        }
    }
    search_response = es_client.search(index=index_name,body=search_query)
    elasticsearch_results.append({
        'true_id': document_id,
        'retrieved_ids': [hit['_source']['id'] for hit in search_response['hits']['hits']]
    })
print('all done')
# Out:
# 100%|██████████| 4627/4627 [00:16<00:00, 286.63it/s]
# all done

# %%
for res in elasticsearch_results[:5]:
    print(f"Id: {res['true_id']} -> Retrieved Ids: {res['retrieved_ids']}")
# Out:
# Id: c02e79ef -> Retrieved Ids: ['c02e79ef', '1f6520ca', '7842b56a', '63394d91', 'a482086d']
# Id: c02e79ef -> Retrieved Ids: ['eb56ae98', '63394d91', 'a482086d', '7842b56a', '2f19301f']
# Id: c02e79ef -> Retrieved Ids: ['0e424a44', '1f6520ca', '04aa4897', '29865466', '63394d91']
# Id: c02e79ef -> Retrieved Ids: ['0bbf41ec', '63394d91', 'a482086d', '2f19301f', '7842b56a']
# Id: c02e79ef -> Retrieved Ids: ['7842b56a', '4eefdd01', '8dc77677', 'a1603359', '63394d91']

# %%
def hit_rate(results):
    total = 0
    for res in results:
        if res['true_id'] in res['retrieved_ids']:
            total+= 1 
    return total / len(results)

def mmr(results):
    total = 0
    for res in results:
        if res['true_id'] in res['retrieved_ids']:
            rank = res['retrieved_ids'].index(res['true_id']) + 1
            total += 1 / rank
    return total / len(results)

def recall_at_k(results, k):
    total = 0
    for res in results:
        if res['true_id'] in res['retrieved_ids'][:k]:
            total += 1
    return total / len(results)

# %%
print(f"Hit Rate: {hit_rate(elasticsearch_results)}")
print(f"MMR: {mmr(elasticsearch_results)}")
print(f"Recall@3: {recall_at_k(elasticsearch_results, 3)}")
# Out:
# Hit Rate: 0.7393559541819754
# MMR: 0.6023233196455591
# Recall@3: 0.6699805489518046

# %%
import minsearch
Index = minsearch.Index(
    text_fields = ['text','section','question'],
    keyword_fields = ['course']) 

Index.fit(docs)
# Out:
# /home/gwm-279/Documents/DTC_AI/Rag_evaluation/minsearch.py:10: UserWarning: Now minsearch is installable via pip: 'pip install minsearch'. Remove the downloaded file and re-install it with pip.
#   warnings.warn(

# %%
minsearch_results = [] 
def search_with_minsearch(gt_questions):

    for index, row in tqdm(gt_questions.iterrows(), total=len(gt_questions)):
        query = row['question']
        course = row['course']
        document_id = row['document']
        num_results = 5
        results = Index.search(query, filter_dict={'course': course}, num_results=num_results)

        minsearch_results.append({
            'true_id': document_id,
            'retrieved_ids': [res['id'] for res in results]
        })
    return minsearch_results

search_with_minsearch(gt_questions)
# Out:
# 100%|██████████| 4627/4627 [00:10<00:00, 424.95it/s]
# [{'true_id': 'c02e79ef',
#   'retrieved_ids': ['c02e79ef',
#    'a482086d',
#    '7842b56a',
#    '63394d91',
#    '1f6520ca']},
#  {'true_id': 'c02e79ef',
#   'retrieved_ids': ['a482086d',
#    'c02e79ef',
#    '2f19301f',
#    'eb56ae98',
#    '63394d91']},
#  {'true_id': 'c02e79ef',
#   'retrieved_ids': ['c02e79ef',
#    '1f6520ca',
#    '04aa4897',
#    '0e424a44',
#    '29865466']},
#  {'true_id': 'c02e79ef',
#   'retrieved_ids': ['c02e79ef',
#    'a482086d',
#    '2f19301f',
#    '63394d91',
#    '0bbf41ec']},
#  {'true_id': 'c02e79ef',
#   'retrieved_ids': ['c02e79ef',
#    'bba0da04',
#    '7842b56a',
#    'a2120335',
#    '009ac612']},
#  {'true_id': '1f6520ca',
#   'retrieved_ids': ['1f6520ca',
#    '63394d91',
#    'c02e79ef',
#    'a482086d',
#    'f2945cd2']},
#  {'true_id': '1f6520ca',
#   'retrieved_ids': ['1f6520ca',
#    'f2945cd2',
#    '63394d91',
#    'c02e79ef',
#    'a482086d']},
#  {'true_id': '1f6520ca',
#   'retrieved_ids': ['1f6520ca',
#    'c02e79ef',
#    '63394d91',
#    'a482086d',
#    '7842b56a']},
#  {'true_id': '1f6520ca',
#   'retrieved_ids': ['1f6520ca',
#    'c02e79ef',
#    '63394d91',
#    'f2945cd2',
#    'a482086d']},
#  {'true_id': '1f6520ca',
#   'retrieved_ids': ['1f6520ca',
#    'c02e79ef',
#    '63394d91',
#    'a482086d',
#    'b2799574']},
#  {'true_id': '7842b56a',
#   'retrieved_ids': ['a482086d',
#    '63394d91',
#    'c02e79ef',
#    '7842b56a',
#    'cb257ee5']},
#  {'true_id': '7842b56a',
#   'retrieved_ids': ['be5bfee4',
#    'b2799574',
#    'e4a7c3b0',
#    '0bbf41ec',
#    '48b533a8']},
#  {'true_id': '7842b56a',
#   'retrieved_ids': ['be5bfee4',
#    '7842b56a',
#    '504b8570',
#    '016d46a1',
#    '29865466']},
#  {'true_id': '7842b56a',
#   'retrieved_ids': ['7842b56a',
#    'be5bfee4',
#    'a1daf537',
#    '3e0114ad',
#    'cbca4495']},
#  {'true_id': '7842b56a',
#   'retrieved_ids': ['c02e79ef',
#    '7842b56a',
#    'be5bfee4',
#    'a482086d',
#    '63394d91']},
#  {'true_id': '0bbf41ec',
#   'retrieved_ids': ['0bbf41ec',
#    '155aa868',
#    '315ac3cc',
#    '04656af5',
#    'b6fdd91d']},
#  {'true_id': '0bbf41ec',
#   'retrieved_ids': ['0bbf41ec',
#    '04656af5',
#    '351a078a',
#    '315ac3cc',
#    'b6fdd91d']},
#  {'true_id': '0bbf41ec',
#   'retrieved_ids': ['0bbf41ec',
#    '315ac3cc',
#    '04656af5',
#    '1835bfe0',
#    '1023ee65']},
#  {'true_id': '0bbf41ec',
#   'retrieved_ids': ['0bbf41ec',
#    'c02e79ef',
#    '1f6520ca',
#    '7842b56a',
#    '04656af5']},
#  {'true_id': '0bbf41ec',
#   'retrieved_ids': ['0bbf41ec',
#    '04656af5',
#    'a2120335',
#    '315ac3cc',
#    'bba0da04']},
#  {'true_id': '63394d91', 'retrieved_ids': []},
#  {'true_id': '63394d91', 'retrieved_ids': []},
#  {'true_id': '63394d91', 'retrieved_ids': []},
#  {'true_id': '63394d91', 'retrieved_ids': []},
#  {'true_id': '63394d91', 'retrieved_ids': []},
#  {'true_id': '2ed9b986',
#   'retrieved_ids': ['2ed9b986',
#    '52393fb3',
#    '10515af5',
#    '04aa4897',
#    'ea739c65']},
#  {'true_id': '2ed9b986',
#   'retrieved_ids': ['c02e79ef',
#    '2ed9b986',
#    '1f6520ca',
#    '04aa4897',
#    '10515af5']},
#  {'true_id': '2ed9b986',
#   'retrieved_ids': ['155aa868',
#    '690ba010',
#    'b6fdd91d',
#    '04656af5',
#    'ebd63566']},
#  {'true_id': '2ed9b986',
#   'retrieved_ids': ['04656af5',
#    '155aa868',
#    'b6fdd91d',
#    '2ed9b986',
#    '1023ee65']},
#  {'true_id': '2ed9b986',
#   'retrieved_ids': ['009ac612',
#    '2ed9b986',
#    'e265ee5a',
#    'a482086d',
#    'eb56ae98']},
#  {'true_id': '93e2c8ed',
#   'retrieved_ids': ['ffbf3311',
#    '93e2c8ed',
#    '3916f4a9',
#    '305aead7',
#    'f0617e65']},
#  {'true_id': '93e2c8ed',
#   'retrieved_ids': ['93e2c8ed',
#    '29d3d343',
#    '8dc77677',
#    'df8ea7e8',
#    '06021091']},
#  {'true_id': '93e2c8ed',
#   'retrieved_ids': ['93e2c8ed',
#    'c02e79ef',
#    '0a059700',
#    'b2799574',
#    'a482086d']},
#  {'true_id': '93e2c8ed',
#   'retrieved_ids': ['93e2c8ed',
#    'c02e79ef',
#    '009ac612',
#    'f7252f17',
#    'e265ee5a']},
#  {'true_id': '93e2c8ed',
#   'retrieved_ids': ['93e2c8ed',
#    '0a059700',
#    'ffbf3311',
#    'b2799574',
#    'a7cecdf9']},
#  {'true_id': 'a482086d',
#   'retrieved_ids': ['a482086d',
#    'c02e79ef',
#    '7842b56a',
#    '63394d91',
#    'eb56ae98']},
#  {'true_id': 'a482086d',
#   'retrieved_ids': ['a482086d',
#    'c02e79ef',
#    'b2799574',
#    '0e424a44',
#    '29865466']},
#  {'true_id': 'a482086d',
#   'retrieved_ids': ['a482086d',
#    'c02e79ef',
#    '7842b56a',
#    'cb257ee5',
#    '63394d91']},
#  {'true_id': 'a482086d',
#   'retrieved_ids': ['93e2c8ed',
#    '74c361fe',
#    'a482086d',
#    '10515af5',
#    'c02e79ef']},
#  {'true_id': 'a482086d',
#   'retrieved_ids': ['6cb3b4a9',
#    '5959ea3c',
#    'a482086d',
#    '3e0114ad',
#    '7842b56a']},
#  {'true_id': 'eb56ae98',
#   'retrieved_ids': ['cb257ee5',
#    'eb56ae98',
#    'a482086d',
#    'c02e79ef',
#    '0bbf41ec']},
#  {'true_id': 'eb56ae98',
#   'retrieved_ids': ['cb257ee5',
#    'eb56ae98',
#    '04aa4897',
#    'ffbf3311',
#    'a820b9b3']},
#  {'true_id': 'eb56ae98',
#   'retrieved_ids': ['7a71fa2c',
#    '9336ce2c',
#    '4292531b',
#    '2d4e434f',
#    'a85a6a91']},
#  {'true_id': 'eb56ae98',
#   'retrieved_ids': ['cb257ee5',
#    'eb56ae98',
#    'c02e79ef',
#    'a482086d',
#    '2f19301f']},
#  {'true_id': 'eb56ae98',
#   'retrieved_ids': ['c02e79ef',
#    'eb56ae98',
#    'a482086d',
#    '1f6520ca',
#    'a820b9b3']},
#  {'true_id': '4292531b',
#   'retrieved_ids': ['4292531b',
#    'c02e79ef',
#    'a482086d',
#    '63394d91',
#    '7842b56a']},
#  {'true_id': '4292531b',
#   'retrieved_ids': ['f2945cd2',
#    '2f19301f',
#    'c02e79ef',
#    'a482086d',
#    '7842b56a']},
#  {'true_id': '4292531b',
#   'retrieved_ids': ['9681be3b',
#    '4292531b',
#    '4eefdd01',
#    '2ed9b986',
#    '04aa4897']},
#  {'true_id': '4292531b',
#   'retrieved_ids': ['4292531b',
#    '04656af5',
#    '315ac3cc',
#    'b6fdd91d',
#    '155aa868']},
#  {'true_id': '4292531b',
#   'retrieved_ids': ['4292531b',
#    'ffbf3311',
#    'c0d3a2e8',
#    '009ac612',
#    '3916f4a9']},
#  {'true_id': 'ea739c65',
#   'retrieved_ids': ['ea739c65',
#    'f2945cd2',
#    'c02e79ef',
#    '2ed9b986',
#    '9681be3b']},
#  {'true_id': 'ea739c65',
#   'retrieved_ids': ['ea739c65',
#    '1f6520ca',
#    'c02e79ef',
#    'f2945cd2',
#    'a482086d']},
#  {'true_id': 'ea739c65',
#   'retrieved_ids': ['c02e79ef',
#    'ea739c65',
#    'f2945cd2',
#    'eb56ae98',
#    '1f6520ca']},
#  {'true_id': 'ea739c65',
#   'retrieved_ids': ['1f6520ca',
#    'ea739c65',
#    'c02e79ef',
#    'f2945cd2',
#    '63394d91']},
#  {'true_id': 'ea739c65',
#   'retrieved_ids': ['ea739c65',
#    'f2945cd2',
#    '9681be3b',
#    'c02e79ef',
#    '2ed9b986']},
#  {'true_id': 'cb257ee5',
#   'retrieved_ids': ['cb257ee5',
#    'a482086d',
#    'c02e79ef',
#    'eb56ae98',
#    '2f19301f']},
#  {'true_id': 'cb257ee5',
#   'retrieved_ids': ['cb257ee5',
#    'bb1ba786',
#    '6cb3b4a9',
#    '3184bd8b',
#    '0002ab8b']},
#  {'true_id': 'cb257ee5',
#   'retrieved_ids': ['cb257ee5',
#    'eb56ae98',
#    'c02e79ef',
#    'ea739c65',
#    'a482086d']},
#  {'true_id': 'cb257ee5',
#   'retrieved_ids': ['cb257ee5',
#    'ffbf3311',
#    '3916f4a9',
#    '7842b56a',
#    'bb1ba786']},
#  {'true_id': 'cb257ee5',
#   'retrieved_ids': ['c02e79ef',
#    'cb257ee5',
#    '1f6520ca',
#    'a482086d',
#    '63394d91']},
#  {'true_id': '04aa4897',
#   'retrieved_ids': ['04aa4897',
#    '9681be3b',
#    '97170587',
#    '70d83d78',
#    '0728ca67']},
#  {'true_id': '04aa4897',
#   'retrieved_ids': ['04aa4897',
#    '9681be3b',
#    '97170587',
#    '0728ca67',
#    '154d7705']},
#  {'true_id': '04aa4897',
#   'retrieved_ids': ['04aa4897',
#    'a1603359',
#    '4eefdd01',
#    'a2120335',
#    '16c16ff9']},
#  {'true_id': '04aa4897',
#   'retrieved_ids': ['04aa4897',
#    '52393fb3',
#    'a820b9b3',
#    '9681be3b',
#    '7c700adb']},
#  {'true_id': '04aa4897',
#   'retrieved_ids': ['52393fb3',
#    '04aa4897',
#    'a820b9b3',
#    'ddf6c1b3',
#    '9681be3b']},
#  {'true_id': '9681be3b',
#   'retrieved_ids': ['9681be3b',
#    '04aa4897',
#    'c02e79ef',
#    'f01df45b',
#    '52393fb3']},
#  {'true_id': '9681be3b',
#   'retrieved_ids': ['97170587',
#    '70d83d78',
#    '0728ca67',
#    '773587dd',
#    '68842c02']},
#  {'true_id': '9681be3b',
#   'retrieved_ids': ['9681be3b',
#    '04aa4897',
#    '52393fb3',
#    '0002ab8b',
#    '93e2c8ed']},
#  {'true_id': '9681be3b',
#   'retrieved_ids': ['9681be3b',
#    '04aa4897',
#    'f01df45b',
#    'ea739c65',
#    '2fdc5057']},
#  {'true_id': '9681be3b',
#   'retrieved_ids': ['9681be3b',
#    '04aa4897',
#    '52393fb3',
#    'f01df45b',
#    'bba0da04']},
#  {'true_id': 'a1daf537',
#   'retrieved_ids': ['a1daf537',
#    '4eefdd01',
#    '8dc77677',
#    '50bd1a71',
#    'a1603359']},
#  {'true_id': 'a1daf537',
#   'retrieved_ids': ['a1daf537',
#    '32e8450c',
#    'cbca4495',
#    '7842b56a',
#    '954044d1']},
#  {'true_id': 'a1daf537',
#   'retrieved_ids': ['5959ea3c',
#    '6cb3b4a9',
#    'cb478996',
#    '202af70b',
#    'd5b6ef5d']},
#  {'true_id': 'a1daf537',
#   'retrieved_ids': ['32e8450c',
#    'a1daf537',
#    'd061525d',
#    'f96517d9',
#    '1cd746c4']},
#  {'true_id': 'a1daf537',
#   'retrieved_ids': ['a1daf537',
#    'bba0da04',
#    'a2120335',
#    '74c361fe',
#    '0e7dfddc']},
#  {'true_id': 'be5bfee4',
#   'retrieved_ids': ['be5bfee4',
#    '4fd37712',
#    '29865466',
#    '7842b56a',
#    '0e424a44']},
#  {'true_id': 'be5bfee4',
#   'retrieved_ids': ['be5bfee4',
#    '7842b56a',
#    '4fd37712',
#    'a1daf537',
#    '71b1984b']},
#  {'true_id': 'be5bfee4',
#   'retrieved_ids': ['be5bfee4',
#    '3e0114ad',
#    '0e424a44',
#    'ddf6c1b3',
#    'a1daf537']},
#  {'true_id': 'be5bfee4',
#   'retrieved_ids': ['be5bfee4',
#    'a1daf537',
#    '0002ab8b',
#    '0e424a44',
#    'edbae698']},
#  {'true_id': 'be5bfee4',
#   'retrieved_ids': ['4fd37712',
#    'be5bfee4',
#    'f01df45b',
#    'bba0da04',
#    'e265ee5a']},
#  {'true_id': '0e424a44',
#   'retrieved_ids': ['0e424a44',
#    '29865466',
#    '68815ec2',
#    'a2120335',
#    'a1daf537']},
#  {'true_id': '0e424a44',
#   'retrieved_ids': ['b9b3ef9f',
#    '0e424a44',
#    'ddf6c1b3',
#    'da899638',
#    '2fdc5057']},
#  {'true_id': '0e424a44',
#   'retrieved_ids': ['2f19301f',
#    '0e424a44',
#    '9c85f3aa',
#    '3e0114ad',
#    'be5bfee4']},
#  {'true_id': '0e424a44',
#   'retrieved_ids': ['0e424a44',
#    'a2120335',
#    '29865466',
#    'b9b3ef9f',
#    '68815ec2']},
#  {'true_id': '0e424a44',
#   'retrieved_ids': ['009ac612',
#    '0e424a44',
#    'a1daf537',
#    '68815ec2',
#    'bba0da04']},
#  {'true_id': '29865466',
#   'retrieved_ids': ['543ff080',
#    'aa244fa0',
#    '29865466',
#    '71c10610',
#    '0282578d']},
#  {'true_id': '29865466',
#   'retrieved_ids': ['29865466',
#    '2f19301f',
#    '016d46a1',
#    'a2120335',
#    '138b55c7']},
#  {'true_id': '29865466',
#   'retrieved_ids': ['29865466',
#    '0002ab8b',
#    '68815ec2',
#    'f2945cd2',
#    '2ed9b986']},
#  {'true_id': '29865466',
#   'retrieved_ids': ['29865466',
#    'ffbf3311',
#    '3916f4a9',
#    '2ed9b986',
#    'f2945cd2']},
#  {'true_id': '29865466',
#   'retrieved_ids': ['29865466',
#    'c02e79ef',
#    'a482086d',
#    '2f19301f',
#    'eb56ae98']},
#  {'true_id': '016d46a1',
#   'retrieved_ids': ['016d46a1',
#    '138b55c7',
#    'bba0da04',
#    '29865466',
#    '0282578d']},
#  {'true_id': '016d46a1',
#   'retrieved_ids': ['016d46a1',
#    'bba0da04',
#    'a2120335',
#    '0282578d',
#    '29865466']},
#  {'true_id': '016d46a1',
#   'retrieved_ids': ['ddf6c1b3',
#    '016d46a1',
#    'c0a46e5d',
#    '6cb3b4a9',
#    'f19be91b']},
#  {'true_id': '016d46a1',
#   'retrieved_ids': ['cd0f9300',
#    '7d217da3',
#    '16370470',
#    '4df80c55',
#    '09081824']},
#  {'true_id': '016d46a1',
#   'retrieved_ids': ['138b55c7',
#    'ddf6c1b3',
#    '016d46a1',
#    '3e0114ad',
#    'c02e79ef']},
#  {'true_id': '47972cb1',
#   'retrieved_ids': ['47972cb1',
#    'c02e79ef',
#    'a482086d',
#    'f2945cd2',
#    '1f6520ca']},
#  {'true_id': '47972cb1',
#   'retrieved_ids': ['b2799574',
#    '316df755',
#    '47972cb1',
#    '3e0114ad',
#    '1520b5bc']},
#  {'true_id': '47972cb1',
#   'retrieved_ids': ['47972cb1',
#    'ffbf3311',
#    '3916f4a9',
#    'd68b433f',
#    '5479dce2']},
#  {'true_id': '47972cb1',
#   'retrieved_ids': ['47972cb1',
#    '2e51a111',
#    '119c917d',
#    '5479dce2',
#    '9681be3b']},
#  {'true_id': '47972cb1',
#   'retrieved_ids': ['47972cb1',
#    'c02e79ef',
#    '316df755',
#    '1f6520ca',
#    'f2945cd2']},
#  {'true_id': 'ddf6c1b3',
#   'retrieved_ids': ['c02e79ef',
#    '1f6520ca',
#    '63394d91',
#    'a482086d',
#    '47972cb1']},
#  {'true_id': 'ddf6c1b3',
#   'retrieved_ids': ['ddf6c1b3',
#    'f2945cd2',
#    'c02e79ef',
#    'a482086d',
#    '3c0114ce']},
#  {'true_id': 'ddf6c1b3',
#   'retrieved_ids': ['ddf6c1b3',
#    'bba0da04',
#    '0282578d',
#    '0513ab8a',
#    '6afb7b55']},
#  {'true_id': 'ddf6c1b3',
#   'retrieved_ids': ['ddf6c1b3',
#    '44b14808',
#    '9c66759f',
#    '5cc0e4d9',
#    'edbae698']},
#  {'true_id': 'ddf6c1b3',
#   'retrieved_ids': ['f2945cd2',
#    'ddf6c1b3',
#    'c02e79ef',
#    '1f6520ca',
#    'b2799574']},
#  {'true_id': 'ac25d3af',
#   'retrieved_ids': ['2f83dbe7',
#    '543ff080',
#    'ac25d3af',
#    '2d653208',
#    '4df80c55']},
#  {'true_id': 'ac25d3af',
#   'retrieved_ids': ['ac25d3af',
#    '543ff080',
#    '251218fc',
#    'c599b3a0',
#    '3c41892d']},
#  {'true_id': 'ac25d3af',
#   'retrieved_ids': ['ac25d3af',
#    'ffbf3311',
#    '3916f4a9',
#    '543ff080',
#    '9c85f3aa']},
#  {'true_id': 'ac25d3af',
#   'retrieved_ids': ['543ff080',
#    'ac25d3af',
#    '7d067f5c',
#    'a6475348',
#    'e866156b']},
#  {'true_id': 'ac25d3af',
#   'retrieved_ids': ['ac25d3af',
#    '543ff080',
#    '251218fc',
#    '3c0114ce',
#    'ddf6c1b3']},
#  {'true_id': '251218fc',
#   'retrieved_ids': ['251218fc',
#    'f2945cd2',
#    'ddf6c1b3',
#    '3e0114ad',
#    'ac25d3af']},
#  {'true_id': '251218fc',
#   'retrieved_ids': ['3184bd8b',
#    'ddf6c1b3',
#    '2cb48591',
#    '251218fc',
#    '4f8d9174']},
#  {'true_id': '251218fc',
#   'retrieved_ids': ['43c454c7',
#    'c02e79ef',
#    'f2945cd2',
#    '1f6520ca',
#    '7c700adb']},
#  {'true_id': '251218fc',
#   'retrieved_ids': ['16370470',
#    'ddf6c1b3',
#    '58c9f99f',
#    'e3106e07',
#    'e866156b']},
#  {'true_id': '251218fc',
#   'retrieved_ids': ['a482086d',
#    'c02e79ef',
#    '2f19301f',
#    '10515af5',
#    '3e0114ad']},
#  {'true_id': '3c0114ce',
#   'retrieved_ids': ['3c0114ce',
#    '251218fc',
#    'f2945cd2',
#    '543ff080',
#    'ac25d3af']},
#  {'true_id': '3c0114ce',
#   'retrieved_ids': ['5959ea3c',
#    '6cb3b4a9',
#    '3c0114ce',
#    'ddf6c1b3',
#    'cb478996']},
#  {'true_id': '3c0114ce',
#   'retrieved_ids': ['c02e79ef',
#    '3c0114ce',
#    'e4a7c3b0',
#    'd061525d',
#    'b2799574']},
#  {'true_id': '3c0114ce',
#   'retrieved_ids': ['251218fc',
#    'f2945cd2',
#    'e4a7c3b0',
#    'ddf6c1b3',
#    'c02e79ef']},
#  {'true_id': '3c0114ce',
#   'retrieved_ids': ['3c0114ce',
#    'f2945cd2',
#    'c02e79ef',
#    '1f6520ca',
#    'd061525d']},
#  {'true_id': 'f43f5fe7',
#   'retrieved_ids': ['f43f5fe7',
#    '4f8d9174',
#    '9523c813',
#    '2cb48591',
#    'f10b49be']},
#  {'true_id': 'f43f5fe7',
#   'retrieved_ids': ['f43f5fe7',
#    '3184bd8b',
#    '2cb48591',
#    '4f8d9174',
#    'f10b49be']},
#  {'true_id': 'f43f5fe7',
#   'retrieved_ids': ['f43f5fe7',
#    '33db7dc7',
#    '9523c813',
#    'f10b49be',
#    '2cb48591']},
#  {'true_id': 'f43f5fe7',
#   'retrieved_ids': ['f43f5fe7',
#    '3184bd8b',
#    '9523c813',
#    '2cb48591',
#    'f10b49be']},
#  {'true_id': 'f43f5fe7',
#   'retrieved_ids': ['f43f5fe7',
#    '3184bd8b',
#    '0282578d',
#    '86d11cc0',
#    '9523c813']},
#  {'true_id': 'd061525d',
#   'retrieved_ids': ['d061525d',
#    'c02e79ef',
#    '1f6520ca',
#    'f2945cd2',
#    'e4a7c3b0']},
#  {'true_id': 'd061525d',
#   'retrieved_ids': ['b2799574',
#    'f2945cd2',
#    '3e0114ad',
#    '7cd1912e',
#    'c02e79ef']},
#  {'true_id': 'd061525d',
#   'retrieved_ids': ['a42a7e8c',
#    'd061525d',
#    '1cd01b2c',
#    'f3f13def',
#    '0174dde5']},
#  {'true_id': 'd061525d',
#   'retrieved_ids': ['a42a7e8c',
#    'd061525d',
#    '0282578d',
#    '002d4943',
#    '3c0114ce']},
#  {'true_id': 'd061525d',
#   'retrieved_ids': ['8abeca36',
#    'c489266b',
#    'd061525d',
#    '3184bd8b',
#    'f3f13def']},
#  {'true_id': '1cd01b2c',
#   'retrieved_ids': ['c02e79ef',
#    '1f6520ca',
#    '63394d91',
#    '1cd01b2c',
#    'e4a7c3b0']},
#  {'true_id': '1cd01b2c',
#   'retrieved_ids': ['4f8d9174',
#    '3184bd8b',
#    'e4a7c3b0',
#    '2fdc5057',
#    'b2799574']},
#  {'true_id': '1cd01b2c',
#   'retrieved_ids': ['f2945cd2',
#    '1cd01b2c',
#    '1f6520ca',
#    '0282578d',
#    'c02e79ef']},
#  {'true_id': '1cd01b2c',
#   'retrieved_ids': ['f2945cd2',
#    '63394d91',
#    'c02e79ef',
#    '251218fc',
#    'a482086d']},
#  {'true_id': '1cd01b2c',
#   'retrieved_ids': ['a1fc1a14',
#    'd061525d',
#    '1cd01b2c',
#    '002d4943',
#    '50c009ef']},
#  {'true_id': 'e4a7c3b0',
#   'retrieved_ids': ['e4a7c3b0',
#    '9c66759f',
#    '5cc0e4d9',
#    'd5b6ef5d',
#    '0002ab8b']},
#  {'true_id': 'e4a7c3b0',
#   'retrieved_ids': ['c02e79ef',
#    'a482086d',
#    '63394d91',
#    'e4a7c3b0',
#    '7842b56a']},
#  {'true_id': 'e4a7c3b0',
#   'retrieved_ids': ['e4a7c3b0',
#    'c02e79ef',
#    '7842b56a',
#    'b2799574',
#    'a482086d']},
#  {'true_id': 'e4a7c3b0',
#   'retrieved_ids': ['0282578d',
#    '3c0114ce',
#    'c489266b',
#    '8abeca36',
#    'cb912983']},
#  {'true_id': 'e4a7c3b0',
#   'retrieved_ids': ['c02e79ef',
#    'a482086d',
#    '7842b56a',
#    '63394d91',
#    '2f19301f']},
#  {'true_id': '7cd1912e',
#   'retrieved_ids': ['b2799574',
#    'f2945cd2',
#    '3e0114ad',
#    '7cd1912e',
#    'c02e79ef']},
#  {'true_id': '7cd1912e',
#   'retrieved_ids': ['7cd1912e',
#    'c02e79ef',
#    'f2945cd2',
#    '1f6520ca',
#    'b2799574']},
#  {'true_id': '7cd1912e',
#   'retrieved_ids': ['6cb3b4a9',
#    '5959ea3c',
#    'cb478996',
#    '3cfd16a7',
#    'd5b6ef5d']},
#  {'true_id': '7cd1912e',
#   'retrieved_ids': ['7cd1912e',
#    'acf42bb8',
#    'b2799574',
#    '0bbf41ec',
#    '3e0114ad']},
#  {'true_id': '7cd1912e',
#   'retrieved_ids': ['4eefdd01',
#    'f3f13def',
#    'a2120335',
#    'a1603359',
#    '8dc77677']},
#  {'true_id': '52393fb3',
#   'retrieved_ids': ['52393fb3',
#    '04aa4897',
#    '9681be3b',
#    '2ed9b986',
#    'c02e79ef']},
#  {'true_id': '52393fb3',
#   'retrieved_ids': ['52393fb3',
#    '6cb3b4a9',
#    '9681be3b',
#    'c02e79ef',
#    '04aa4897']},
#  {'true_id': '52393fb3',
#   'retrieved_ids': ['52393fb3',
#    '10515af5',
#    'c02e79ef',
#    '6cb3b4a9',
#    '76e4baf6']},
#  {'true_id': '52393fb3',
#   'retrieved_ids': ['52393fb3',
#    'ffbf3311',
#    '3916f4a9',
#    '6cb3b4a9',
#    '6fdd09eb']},
#  {'true_id': '52393fb3',
#   'retrieved_ids': ['52393fb3',
#    'a820b9b3',
#    '7cd1912e',
#    'eb56ae98',
#    'f2945cd2']},
#  {'true_id': '10515af5',
#   'retrieved_ids': ['a820b9b3',
#    'eb56ae98',
#    '52393fb3',
#    '04aa4897',
#    'c02e79ef']},
#  {'true_id': 'cdb86a97',
#   'retrieved_ids': ['74c361fe',
#    'cdb86a97',
#    '009ac612',
#    'c4e9bc60',
#    'a2120335']},
#  {'true_id': 'cdb86a97',
#   'retrieved_ids': ['cdb86a97',
#    '74c361fe',
#    '68815ec2',
#    '4eefdd01',
#    '009ac612']},
#  {'true_id': 'cdb86a97',
#   'retrieved_ids': ['cdb86a97',
#    '74c361fe',
#    '10515af5',
#    '7d067f5c',
#    '7842b56a']},
#  {'true_id': 'cdb86a97',
#   'retrieved_ids': ['cdb86a97',
#    '74c361fe',
#    '68815ec2',
#    '9c85f3aa',
#    '0e7dfddc']},
#  {'true_id': 'cdb86a97',
#   'retrieved_ids': ['cdb86a97',
#    '4eefdd01',
#    '74c361fe',
#    'a1603359',
#    '8dc77677']},
#  {'true_id': '3e0114ad',
#   'retrieved_ids': ['5959ea3c',
#    '6cb3b4a9',
#    '3e0114ad',
#    'cb478996',
#    'd5b6ef5d']},
#  {'true_id': '3e0114ad',
#   'retrieved_ids': ['a7cecdf9',
#    '3cfd16a7',
#    '5959ea3c',
#    '8e74f943',
#    '6cb3b4a9']},
#  {'true_id': '3e0114ad',
#   'retrieved_ids': ['5959ea3c',
#    '6cb3b4a9',
#    'cb478996',
#    'd5b6ef5d',
#    '74f412c4']},
#  {'true_id': '3e0114ad',
#   'retrieved_ids': ['5959ea3c',
#    '6cb3b4a9',
#    'cb478996',
#    '343864f5',
#    'd5b6ef5d']},
#  {'true_id': '3e0114ad',
#   'retrieved_ids': ['3e0114ad',
#    '5959ea3c',
#    'a7cecdf9',
#    '3cfd16a7',
#    '8e74f943']},
#  {'true_id': 'b2799574',
#   'retrieved_ids': ['3e0114ad',
#    'b2799574',
#    'f2945cd2',
#    '93e2c8ed',
#    'c02e79ef']},
#  {'true_id': 'b2799574',
#   'retrieved_ids': ['b2799574',
#    '3184bd8b',
#    '7cd1912e',
#    '3e0114ad',
#    'a2c7b59f']},
#  {'true_id': 'b2799574',
#   'retrieved_ids': ['1f6520ca',
#    'f2945cd2',
#    'a482086d',
#    'c02e79ef',
#    '63394d91']},
#  {'true_id': 'b2799574',
#   'retrieved_ids': ['be5bfee4',
#    'a2120335',
#    '74c361fe',
#    '1f6520ca',
#    '68815ec2']},
#  {'true_id': 'b2799574',
#   'retrieved_ids': ['c02e79ef',
#    'eb56ae98',
#    'b2799574',
#    'a482086d',
#    '7842b56a']},
#  {'true_id': '2f19301f',
#   'retrieved_ids': ['2f19301f',
#    'c02e79ef',
#    '63394d91',
#    '251218fc',
#    'f2945cd2']},
#  {'true_id': '2f19301f',
#   'retrieved_ids': ['2f19301f',
#    'a482086d',
#    'c02e79ef',
#    '63394d91',
#    '7842b56a']},
#  {'true_id': '2f19301f',
#   'retrieved_ids': ['a9385356',
#    'cdb86a97',
#    '009ac612',
#    '1cd01b2c',
#    'a2120335']},
#  {'true_id': '2f19301f',
#   'retrieved_ids': ['2f19301f',
#    'a482086d',
#    'c02e79ef',
#    '63394d91',
#    '7842b56a']},
#  {'true_id': '2f19301f',
#   'retrieved_ids': ['2f19301f',
#    'c02e79ef',
#    'eb56ae98',
#    'a482086d',
#    'b2799574']},
#  {'true_id': '7c700adb',
#   'retrieved_ids': ['c02e79ef',
#    '7c700adb',
#    'a482086d',
#    '72f25f6d',
#    '63394d91']},
#  {'true_id': '7c700adb',
#   'retrieved_ids': ['f2945cd2',
#    'c02e79ef',
#    'a482086d',
#    '1f6520ca',
#    '3e0114ad']},
#  {'true_id': '7c700adb',
#   'retrieved_ids': ['c02e79ef',
#    'a482086d',
#    '63394d91',
#    '7842b56a',
#    '1f6520ca']},
#  {'true_id': '7c700adb',
#   'retrieved_ids': ['ffbf3311',
#    '3916f4a9',
#    '1023ee65',
#    'adcd914a',
#    '33dd4516']},
#  {'true_id': '7c700adb',
#   'retrieved_ids': ['f2945cd2',
#    'c02e79ef',
#    '1f6520ca',
#    '7c700adb',
#    '29865466']},
#  {'true_id': '44b14808',
#   'retrieved_ids': ['44b14808',
#    '3184bd8b',
#    'edbae698',
#    'c9375c56',
#    '154d7705']},
#  {'true_id': '44b14808',
#   'retrieved_ids': ['44b14808',
#    'c9375c56',
#    'fd714677',
#    '3ef0bb96',
#    '0a059700']},
#  {'true_id': '44b14808',
#   'retrieved_ids': ['44b14808',
#    '72f25f6d',
#    '0002ab8b',
#    'b51c3b82',
#    '17090545']},
#  {'true_id': '44b14808',
#   'retrieved_ids': ['97170587',
#    '70d83d78',
#    '0728ca67',
#    '94fd2476',
#    'accb7285']},
#  {'true_id': '44b14808',
#   'retrieved_ids': ['44b14808',
#    'ffbf3311',
#    '3916f4a9',
#    '17090545',
#    'ce508f3c']},
#  {'true_id': '76e4baf6',
#   'retrieved_ids': ['76e4baf6',
#    'c02e79ef',
#    '1f6520ca',
#    'a482086d',
#    '7842b56a']},
#  {'true_id': '76e4baf6',
#   'retrieved_ids': ['76e4baf6',
#    'f2945cd2',
#    'a482086d',
#    'c02e79ef',
#    '3e0114ad']},
#  {'true_id': '76e4baf6',
#   'retrieved_ids': ['bba0da04',
#    'a4ba2478',
#    '0e7dfddc',
#    '251218fc',
#    '74c361fe']},
#  {'true_id': '76e4baf6',
#   'retrieved_ids': ['c02e79ef',
#    '47972cb1',
#    'a482086d',
#    '7842b56a',
#    'b2799574']},
#  {'true_id': '76e4baf6',
#   'retrieved_ids': ['a482086d',
#    'f2945cd2',
#    'c02e79ef',
#    '1f6520ca',
#    '2f19301f']},
#  {'true_id': '48b533a8',
#   'retrieved_ids': ['5959ea3c',
#    '48b533a8',
#    'cb478996',
#    '6cb3b4a9',
#    'd5b6ef5d']},
#  {'true_id': '48b533a8',
#   'retrieved_ids': ['5959ea3c',
#    '6cb3b4a9',
#    '48b533a8',
#    'cb478996',
#    'd5b6ef5d']},
#  {'true_id': '48b533a8',
#   'retrieved_ids': ['5959ea3c',
#    'cb478996',
#    '6cb3b4a9',
#    'd5b6ef5d',
#    'a73ed357']},
#  {'true_id': '48b533a8',
#   'retrieved_ids': ['5959ea3c',
#    '6cb3b4a9',
#    'cb478996',
#    'f2705fe7',
#    'b406d90e']},
#  {'true_id': '48b533a8',
#   'retrieved_ids': ['5959ea3c',
#    '6cb3b4a9',
#    'cb478996',
#    'd5b6ef5d',
#    '343864f5']},
#  {'true_id': '954044d1',
#   'retrieved_ids': ['954044d1',
#    'a2120335',
#    'bba0da04',
#    '68815ec2',
#    'f10b49be']},
#  {'true_id': '954044d1',
#   'retrieved_ids': ['ffbf3311',
#    '4fd37712',
#    '68815ec2',
#    'f3f13def',
#    'c65d8fd9']},
#  {'true_id': '954044d1',
#   'retrieved_ids': ['ddf6c1b3',
#    'a820b9b3',
#    'bba0da04',
#    '0282578d',
#    '954044d1']},
#  {'true_id': '954044d1',
#   'retrieved_ids': ['a820b9b3',
#    'd061525d',
#    '1cd01b2c',
#    'eb9d376f',
#    'c02e79ef']},
#  {'true_id': '954044d1',
#   'retrieved_ids': ['bba0da04',
#    '7f845a1c',
#    '63394d91',
#    '3b711e73',
#    '2b7a8512']},
#  {'true_id': 'a820b9b3',
#   'retrieved_ids': ['a820b9b3',
#    'f3f13def',
#    '009ac612',
#    '74c361fe',
#    'c65d8fd9']},
#  {'true_id': 'a820b9b3',
#   'retrieved_ids': ['a820b9b3',
#    'ddf6c1b3',
#    '68842c02',
#    '4ca14331',
#    '4bd23594']},
#  {'true_id': 'a820b9b3',
#   'retrieved_ids': ['009ac612',
#    '74c361fe',
#    'c65d8fd9',
#    '16c16ff9',
#    'a2120335']},
#  {'true_id': 'a820b9b3',
#   'retrieved_ids': ['251218fc',
#    'a820b9b3',
#    '3184bd8b',
#    '3e5d1e9b',
#    '351a078a']},
#  {'true_id': 'a820b9b3',
#   'retrieved_ids': ['bba0da04',
#    'a2120335',
#    'a4ba2478',
#    '0a059700',
#    '74c361fe']},
#  {'true_id': 'f2945cd2',
#   'retrieved_ids': ['f2945cd2',
#    '1f6520ca',
#    '251218fc',
#    'c02e79ef',
#    '63394d91']},
#  {'true_id': 'f2945cd2',
#   'retrieved_ids': ['f2945cd2',
#    '9c85f3aa',
#    '5cc0e4d9',
#    '4eefdd01',
#    '3e0114ad']},
#  {'true_id': 'f2945cd2',
#   'retrieved_ids': ['ffbf3311',
#    '3916f4a9',
#    '0513ab8a',
#    'f2945cd2',
#    '9c85f3aa']},
#  {'true_id': 'f2945cd2',
#   'retrieved_ids': ['ffbf3311',
#    'f2945cd2',
#    '3916f4a9',
#    '9c85f3aa',
#    '543ff080']},
#  {'true_id': 'f2945cd2',
#   'retrieved_ids': ['954044d1',
#    'f2945cd2',
#    '2f83dbe7',
#    '0513ab8a',
#    '66e117dd']},
#  {'true_id': 'eb9d376f',
#   'retrieved_ids': ['eb9d376f',
#    'bba0da04',
#    '8abeca36',
#    'a2120335',
#    '6497b659']},
#  {'true_id': 'eb9d376f',
#   'retrieved_ids': ['eb9d376f',
#    'ffbf3311',
#    '3916f4a9',
#    '5eaf61fe',
#    '77410975']},
#  {'true_id': 'eb9d376f',
#   'retrieved_ids': ['a2120335',
#    'eb9d376f',
#    'f3f13def',
#    'bba0da04',
#    'f7252f17']},
#  {'true_id': 'eb9d376f',
#   'retrieved_ids': ['eb9d376f',
#    'a2120335',
#    '4fd37712',
#    'f7252f17',
#    '74c361fe']},
#  {'true_id': 'eb9d376f',
#   'retrieved_ids': ['eb9d376f',
#    '954044d1',
#    'ffbf3311',
#    '6497b659',
#    'f2945cd2']},
#  {'true_id': '72f25f6d',
#   'retrieved_ids': ['72f25f6d',
#    '71b1984b',
#    '859a97c5',
#    '5eaf61fe',
#    '8b14286c']},
#  {'true_id': '72f25f6d',
#   'retrieved_ids': ['71b1984b',
#    '2fdc5057',
#    '33db7dc7',
#    '351a078a',
#    'c599b3a0']},
#  {'true_id': '72f25f6d',
#   'retrieved_ids': ['72f25f6d',
#    '1ea7680e',
#    'a6475348',
#    'f7252f17',
#    '2f19301f']},
#  {'true_id': '72f25f6d',
#   'retrieved_ids': ['72f25f6d',
#    'edbae698',
#    'e7bdbba6',
#    'bba0da04',
#    'a2120335']},
#  {'true_id': '72f25f6d',
#   'retrieved_ids': ['72f25f6d',
#    'a8657e65',
#    '5eaf61fe',
#    'a2120335',
#    '859a97c5']},
#  {'true_id': 'a1e59afc',
#   'retrieved_ids': ['a1e59afc',
#    '2cb48591',
#    '9523c813',
#    '32e8450c',
#    '3aee7261']},
#  {'true_id': 'a1e59afc',
#   'retrieved_ids': ['a1e59afc',
#    '3916f4a9',
#    'ffbf3311',
#    '3184bd8b',
#    'bba0da04']},
#  {'true_id': 'a1e59afc',
#   'retrieved_ids': ['bba0da04',
#    'f7252f17',
#    'a2120335',
#    '74c361fe',
#    'a4ba2478']},
#  {'true_id': 'a1e59afc',
#   'retrieved_ids': ['4eefdd01',
#    '74c361fe',
#    '009ac612',
#    'a1e59afc',
#    '71c10610']},
#  {'true_id': 'a1e59afc',
#   'retrieved_ids': ['71c10610',
#    '5a275db7',
#    '8b71a398',
#    '33dd4516',
#    '9336ce2c']},
#  {'true_id': '71c10610',
#   'retrieved_ids': ['71c10610',
#    'c489266b',
#    'f83d9435',
#    '04656af5',
#    '155aa868']},
#  {'true_id': '71c10610',
#   'retrieved_ids': ['71c10610',
#    'c489266b',
#    '8b71a398',
#    '155aa868',
#    'f83d9435']},
#  {'true_id': '71c10610',
#   'retrieved_ids': ['71c10610',
#    'f55efcf0',
#    'ffbf3311',
#    '3916f4a9',
#    '33dd4516']},
#  {'true_id': '71c10610',
#   'retrieved_ids': ['71c10610',
#    '04656af5',
#    'e78cf960',
#    '155aa868',
#    'b6fdd91d']},
#  {'true_id': '71c10610',
#   'retrieved_ids': ['8b71a398',
#    '71c10610',
#    'c489266b',
#    'e265ee5a',
#    '752e8452']},
#  {'true_id': '17a5aea1',
#   'retrieved_ids': ['17a5aea1',
#    '04656af5',
#    '1835bfe0',
#    'b6fdd91d',
#    '155aa868']},
#  {'true_id': '17a5aea1',
#   'retrieved_ids': ['17a5aea1',
#    '04656af5',
#    '74c361fe',
#    'b6fdd91d',
#    '155aa868']},
#  {'true_id': '17a5aea1',
#   'retrieved_ids': ['17a5aea1',
#    '315ac3cc',
#    '71c10610',
#    '155aa868',
#    '04656af5']},
#  {'true_id': '17a5aea1',
#   'retrieved_ids': ['17a5aea1',
#    '04656af5',
#    '74c361fe',
#    '315ac3cc',
#    'b6fdd91d']},
#  {'true_id': '17a5aea1',
#   'retrieved_ids': ['4eefdd01',
#    '315ac3cc',
#    '10acd478',
#    'a1603359',
#    '14a876ea']},
#  {'true_id': '5a275db7',
#   'retrieved_ids': ['5a275db7',
#    'ffbf3311',
#    '33dd4516',
#    '3916f4a9',
#    '3fe85b16']},
#  {'true_id': '5a275db7',
#   'retrieved_ids': ['5a275db7',
#    '71c10610',
#    '8b71a398',
#    '9336ce2c',
#    '33dd4516']},
#  {'true_id': '5a275db7',
#   'retrieved_ids': ['8b71a398',
#    '752e8452',
#    '71c10610',
#    'eac816d7',
#    '5a275db7']},
#  {'true_id': '5a275db7',
#   'retrieved_ids': ['5eaf61fe',
#    '676e1b76',
#    '74c361fe',
#    '2aadd232',
#    'a2120335']},
#  {'true_id': '5a275db7',
#   'retrieved_ids': ['5a275db7',
#    '8b71a398',
#    'aa244fa0',
#    'd68b433f',
#    'f2705fe7']},
#  {'true_id': '7ec0f9b0',
#   'retrieved_ids': ['a820b9b3',
#    'eb56ae98',
#    '52393fb3',
#    '04aa4897',
#    'c02e79ef']},
#  {'true_id': 'bb1ba786',
#   'retrieved_ids': ['bb1ba786',
#    'ffbf3311',
#    '3916f4a9',
#    'd970a0da',
#    '489c366f']},
#  {'true_id': 'bb1ba786',
#   'retrieved_ids': ['ffbf3311',
#    'bb1ba786',
#    'd970a0da',
#    '3916f4a9',
#    '489c366f']},
#  {'true_id': 'bb1ba786',
#   'retrieved_ids': ['bb1ba786',
#    '5479dce2',
#    'cb257ee5',
#    '7ec0f9b0',
#    '859a97c5']},
#  {'true_id': 'bb1ba786',
#   'retrieved_ids': ['bb1ba786',
#    '7ec0f9b0',
#    'cb257ee5',
#    'a2120335',
#    '16c16ff9']},
#  {'true_id': 'bb1ba786',
#   'retrieved_ids': ['bb1ba786',
#    'ffbf3311',
#    '3916f4a9',
#    '954044d1',
#    'cb257ee5']},
#  {'true_id': '2f83dbe7',
#   'retrieved_ids': ['2f83dbe7',
#    'f2945cd2',
#    'ffbf3311',
#    '3916f4a9',
#    'fd714677']},
#  {'true_id': '2f83dbe7',
#   'retrieved_ids': ['2f83dbe7',
#    'ffbf3311',
#    '3916f4a9',
#    'fd714677',
#    'f7252f17']},
#  {'true_id': '2f83dbe7',
#   'retrieved_ids': ['2f83dbe7',
#    'ffbf3311',
#    'fd714677',
#    '3916f4a9',
#    '70d83d78']},
#  {'true_id': '2f83dbe7',
#   'retrieved_ids': ['2f83dbe7',
#    'ffbf3311',
#    'f2945cd2',
#    '3916f4a9',
#    'fd714677']},
#  {'true_id': '2f83dbe7',
#   'retrieved_ids': ['2f83dbe7',
#    'ffbf3311',
#    '6fdd09eb',
#    '3916f4a9',
#    'fd714677']},
#  {'true_id': '543ff080',
#   'retrieved_ids': ['543ff080',
#    'ffbf3311',
#    '251218fc',
#    'ac25d3af',
#    '3916f4a9']},
#  {'true_id': '543ff080',
#   'retrieved_ids': ['543ff080',
#    '4eefdd01',
#    'a1603359',
#    '1ebb9a47',
#    '251218fc']},
#  {'true_id': '543ff080',
#   'retrieved_ids': ['543ff080',
#    'ac25d3af',
#    '251218fc',
#    'ddf6c1b3',
#    '1ebb9a47']},
#  {'true_id': '543ff080',
#   'retrieved_ids': ['543ff080',
#    '0002ab8b',
#    'ac25d3af',
#    '251218fc',
#    'f2945cd2']},
#  {'true_id': '543ff080',
#   'retrieved_ids': ['543ff080',
#    'ffbf3311',
#    'ac25d3af',
#    '3916f4a9',
#    '251218fc']},
#  {'true_id': 'd407d65b',
#   'retrieved_ids': ['d407d65b',
#    '0882bfac',
#    'e866156b',
#    'fb930700',
#    '58c9f99f']},
#  {'true_id': 'd407d65b',
#   'retrieved_ids': ['d407d65b',
#    'e866156b',
#    '09081824',
#    '316df755',
#    'aa187680']},
#  {'true_id': 'd407d65b',
#   'retrieved_ids': ['316df755',
#    'd407d65b',
#    'fb930700',
#    'e866156b',
#    '32e8450c']},
#  {'true_id': 'd407d65b',
#   'retrieved_ids': ['d407d65b',
#    'e866156b',
#    '09081824',
#    '27bdbc3f',
#    'fb930700']},
#  {'true_id': 'd407d65b',
#   'retrieved_ids': ['d407d65b',
#    'fbd3d2bb',
#    'd21bff1d',
#    '0b014d0c',
#    'e866156b']},
#  {'true_id': 'c9375c56',
#   'retrieved_ids': ['316df755',
#    'c9375c56',
#    'a4abe7a5',
#    'f3aa9252',
#    'fb930700']},
#  {'true_id': 'c9375c56',
#   'retrieved_ids': ['316df755',
#    'c9375c56',
#    'a4abe7a5',
#    'f3aa9252',
#    'fb930700']},
#  {'true_id': 'c9375c56',
#   'retrieved_ids': ['316df755',
#    'c9375c56',
#    '4eefdd01',
#    '44b14808',
#    'a1603359']},
#  {'true_id': 'c9375c56',
#   'retrieved_ids': ['316df755',
#    'c9375c56',
#    'f3aa9252',
#    'a4abe7a5',
#    'fb930700']},
#  {'true_id': 'c9375c56',
#   'retrieved_ids': ['bba0da04',
#    '0e7dfddc',
#    'a2120335',
#    '0a059700',
#    '4fd37712']},
#  {'true_id': 'e866156b',
#   'retrieved_ids': ['e866156b',
#    'fb930700',
#    '7d067f5c',
#    '7d217da3',
#    '09081824']},
#  {'true_id': 'e866156b',
#   'retrieved_ids': ['32e8450c',
#    'e866156b',
#    'fbd3d2bb',
#    'fb930700',
#    '0282578d']},
#  {'true_id': 'e866156b',
#   'retrieved_ids': ['e866156b',
#    '196cb0f2',
#    '947213b1',
#    '22a2b9f2',
#    '09081824']},
#  {'true_id': 'e866156b',
#   'retrieved_ids': ['16370470',
#    'e866156b',
#    '0b014d0c',
#    '22a2b9f2',
#    '09081824']},
#  {'true_id': 'e866156b',
#   'retrieved_ids': ['8bea4d53',
#    'f409f751',
#    '22a2b9f2',
#    'e866156b',
#    'c65d8fd9']},
#  {'true_id': '16370470',
#   'retrieved_ids': ['16370470',
#    '0282578d',
#    '0b014d0c',
#    'f476a606',
#    'e866156b']},
#  {'true_id': '16370470',
#   'retrieved_ids': ['16370470',
#    '09081824',
#    '27bdbc3f',
#    '58c9f99f',
#    'e866156b']},
#  {'true_id': '16370470',
#   'retrieved_ids': ['16370470',
#    'e866156b',
#    '7d217da3',
#    'fbd3d2bb',
#    'd407d65b']},
#  {'true_id': '16370470',
#   'retrieved_ids': ['bba0da04',
#    'a2120335',
#    'f3f13def',
#    '16c16ff9',
#    '16370470']},
#  {'true_id': '16370470',
#   'retrieved_ids': ['ffbf3311',
#    'c91ad8f2',
#    'a2120335',
#    'd452b490',
#    'f3f13def']},
#  {'true_id': '316df755',
#   'retrieved_ids': ['316df755',
#    'b36ea564',
#    'f3aa9252',
#    '3aee7261',
#    'c9375c56']},
#  {'true_id': '316df755',
#   'retrieved_ids': ['316df755',
#    'b36ea564',
#    'f3aa9252',
#    '3aee7261',
#    'aa187680']},
#  {'true_id': '316df755',
#   'retrieved_ids': ['316df755',
#    'c9375c56',
#    'f3aa9252',
#    'fb930700',
#    'a4abe7a5']},
#  {'true_id': '316df755',
#   'retrieved_ids': ['316df755',
#    'f3aa9252',
#    'c9375c56',
#    '6497b659',
#    'fb930700']},
#  {'true_id': '316df755',
#   'retrieved_ids': ['316df755',
#    'f3aa9252',
#    'e866156b',
#    'fb930700',
#    'c9375c56']},
#  {'true_id': 'f3aa9252',
#   'retrieved_ids': ['f3aa9252',
#    'b51c3b82',
#    'c9375c56',
#    'd407d65b',
#    '316df755']},
#  {'true_id': 'f3aa9252',
#   'retrieved_ids': ['316df755',
#    'f3aa9252',
#    'a4abe7a5',
#    'c9375c56',
#    'fb930700']},
#  {'true_id': 'f3aa9252',
#   'retrieved_ids': ['316df755',
#    'f3aa9252',
#    '9c66759f',
#    'c9375c56',
#    'b36ea564']},
#  {'true_id': 'f3aa9252',
#   'retrieved_ids': ['f3aa9252',
#    '316df755',
#    'a4abe7a5',
#    'c9375c56',
#    'fb930700']},
#  {'true_id': 'f3aa9252',
#   'retrieved_ids': ['7d067f5c',
#    '2d653208',
#    'e866156b',
#    'fb930700',
#    '316df755']},
#  {'true_id': 'a4abe7a5',
#   'retrieved_ids': ['a4abe7a5',
#    '6497b659',
#    '543ff080',
#    '7d067f5c',
#    'f3aa9252']},
#  {'true_id': 'a4abe7a5',
#   'retrieved_ids': ['a4abe7a5',
#    '316df755',
#    'c9375c56',
#    'f3aa9252',
#    'a146e3ee']},
#  {'true_id': 'a4abe7a5',
#   'retrieved_ids': ['a4abe7a5',
#    '4eefdd01',
#    '8dc77677',
#    'c6db65aa',
#    'e866156b']},
#  {'true_id': 'a4abe7a5',
#   'retrieved_ids': ['a4abe7a5',
#    '6497b659',
#    'c9375c56',
#    'f3aa9252',
#    'fb930700']},
#  {'true_id': 'a4abe7a5',
#   'retrieved_ids': ['a4abe7a5',
#    '316df755',
#    'c9375c56',
#    'f3aa9252',
#    'fb930700']},
#  {'true_id': 'fb930700',
#   'retrieved_ids': ['fb930700',
#    'bba0da04',
#    'a2120335',
#    '16c16ff9',
#    '0a059700']},
#  {'true_id': 'fb930700',
#   'retrieved_ids': ['fb930700',
#    '316df755',
#    'f10b49be',
#    'c9375c56',
#    'e866156b']},
#  {'true_id': 'fb930700',
#   'retrieved_ids': ['fb930700',
#    '3916f4a9',
#    'b000e899',
#    'e866156b',
#    '7d067f5c']},
#  {'true_id': 'fb930700',
#   'retrieved_ids': ['fb930700',
#    '316df755',
#    'a2120335',
#    'c9375c56',
#    'e866156b']},
#  {'true_id': 'fb930700',
#   'retrieved_ids': ['fb930700',
#    'fbd3d2bb',
#    '09081824',
#    'e866156b',
#    'f3aa9252']},
#  {'true_id': 'aa187680',
#   'retrieved_ids': ['aa187680',
#    'f10b49be',
#    '09081824',
#    'c9375c56',
#    '316df755']},
#  {'true_id': 'aa187680',
#   'retrieved_ids': ['aa187680',
#    '09081824',
#    'c8ad08b3',
#    '0a059700',
#    '27bdbc3f']},
#  {'true_id': 'aa187680',
#   'retrieved_ids': ['aa187680',
#    'fb930700',
#    '1cd746c4',
#    '316df755',
#    'c6db65aa']},
#  {'true_id': 'aa187680',
#   'retrieved_ids': ['09081824',
#    'aa187680',
#    '27bdbc3f',
#    '7d217da3',
#    'ffbf3311']},
#  {'true_id': 'aa187680',
#   'retrieved_ids': ['aa187680',
#    'bb6655b9',
#    'b087fa95',
#    'cb912983',
#    '70ac8e80']},
#  {'true_id': 'b000e899',
#   'retrieved_ids': ['b000e899',
#    '50bd1a71',
#    'f409f751',
#    '16370470',
#    'a146e3ee']},
#  {'true_id': 'b000e899',
#   'retrieved_ids': ['b000e899',
#    'ffbf3311',
#    '6497b659',
#    '3916f4a9',
#    'bba0da04']},
#  {'true_id': 'b000e899',
#   'retrieved_ids': ['6497b659',
#    'b000e899',
#    '16370470',
#    '2d653208',
#    '86d11cc0']},
#  {'true_id': 'b000e899',
#   'retrieved_ids': ['b000e899',
#    '16c16ff9',
#    'ffbf3311',
#    '50bd1a71',
#    '72229da5']},
#  {'true_id': 'b000e899',
#   'retrieved_ids': ['fd714677',
#    'c9375c56',
#    'b000e899',
#    '316df755',
#    '16370470']},
#  {'true_id': '9c66759f', 'retrieved_ids': []},
#  {'true_id': '9c66759f', 'retrieved_ids': []},
#  {'true_id': '9c66759f', 'retrieved_ids': []},
#  {'true_id': '9c66759f', 'retrieved_ids': []},
#  {'true_id': '9c66759f', 'retrieved_ids': []},
#  {'true_id': 'e3106e07',
#   'retrieved_ids': ['e3106e07',
#    '58c9f99f',
#    'd21bff1d',
#    '72229da5',
#    'f7252f17']},
#  {'true_id': 'e3106e07',
#   'retrieved_ids': ['e3106e07',
#    'd21bff1d',
#    'a02f2039',
#    '29d3d343',
#    '8bea4d53']},
#  {'true_id': 'e3106e07',
#   'retrieved_ids': ['0b014d0c',
#    'f476a606',
#    '16370470',
#    'c4e9bc60',
#    'e3106e07']},
#  {'true_id': 'e3106e07',
#   'retrieved_ids': ['e3106e07',
#    'a2120335',
#    '58c9f99f',
#    'f7252f17',
#    'f3f13def']},
#  {'true_id': 'e3106e07',
#   'retrieved_ids': ['27bdbc3f',
#    '3916f4a9',
#    'ffbf3311',
#    'e3106e07',
#    '58c9f99f']},
#  {'true_id': '72229da5',
#   'retrieved_ids': ['c02e79ef',
#    'f2945cd2',
#    '29865466',
#    '04aa4897',
#    '63394d91']},
#  {'true_id': '72229da5',
#   'retrieved_ids': ['16370470',
#    '72229da5',
#    '0b014d0c',
#    'b000e899',
#    '16c16ff9']},
#  {'true_id': '72229da5',
#   'retrieved_ids': ['72229da5',
#    'f476a606',
#    'c9375c56',
#    '316df755',
#    'fb930700']},
#  {'true_id': '72229da5',
#   'retrieved_ids': ['0b014d0c',
#    'cbca4495',
#    'e265ee5a',
#    '1f1ecbb7',
#    '72229da5']},
#  {'true_id': '72229da5',
#   'retrieved_ids': ['0b014d0c',
#    '9c66759f',
#    '16370470',
#    'f476a606',
#    'fbd3d2bb']},
#  {'true_id': '58c9f99f',
#   'retrieved_ids': ['58c9f99f',
#    'e3106e07',
#    '72229da5',
#    '04656af5',
#    'b9b3ef9f']},
#  {'true_id': '58c9f99f',
#   'retrieved_ids': ['bba0da04',
#    '316df755',
#    '0b014d0c',
#    'f3aa9252',
#    'c8ad08b3']},
#  {'true_id': '58c9f99f',
#   'retrieved_ids': ['72229da5',
#    '58c9f99f',
#    'f476a606',
#    'fd714677',
#    '316df755']},
#  {'true_id': '58c9f99f',
#   'retrieved_ids': ['58c9f99f',
#    'f476a606',
#    '72229da5',
#    'b6fdd91d',
#    'e3106e07']},
#  {'true_id': '58c9f99f',
#   'retrieved_ids': ['58c9f99f',
#    'e3106e07',
#    '72229da5',
#    'f476a606',
#    '74c361fe']},
#  {'true_id': 'bc42139a',
#   'retrieved_ids': ['bba0da04',
#    'a146e3ee',
#    'bc42139a',
#    'a2120335',
#    '0a059700']},
#  {'true_id': 'bc42139a',
#   'retrieved_ids': ['f476a606',
#    'bc42139a',
#    'fb930700',
#    '72229da5',
#    'e866156b']},
#  {'true_id': 'bc42139a',
#   'retrieved_ids': ['f476a606',
#    'a2120335',
#    '16c16ff9',
#    'fb930700',
#    '0a059700']},
#  {'true_id': 'bc42139a',
#   'retrieved_ids': ['09081824',
#    '27bdbc3f',
#    'e866156b',
#    'fb930700',
#    '3e5d1e9b']},
#  {'true_id': 'bc42139a',
#   'retrieved_ids': ['09081824',
#    '27bdbc3f',
#    '58c9f99f',
#    'e866156b',
#    '176ce516']},
#  {'true_id': 'a146e3ee',
#   'retrieved_ids': ['a146e3ee',
#    '50bd1a71',
#    '68815ec2',
#    '0a059700',
#    'e265ee5a']},
#  {'true_id': 'a146e3ee',
#   'retrieved_ids': ['a146e3ee',
#    '1e50eab7',
#    'd21bff1d',
#    '8bea4d53',
#    'e866156b']},
#  {'true_id': 'a146e3ee',
#   'retrieved_ids': ['b9b3ef9f',
#    'a2120335',
#    'a146e3ee',
#    'e265ee5a',
#    '74c361fe']},
#  {'true_id': 'a146e3ee',
#   'retrieved_ids': ['d21bff1d',
#    'a146e3ee',
#    'e3106e07',
#    'c6db65aa',
#    'f409f751']},
#  {'true_id': 'a146e3ee',
#   'retrieved_ids': ['a146e3ee',
#    '4eefdd01',
#    '8dc77677',
#    'c9375c56',
#    'e866156b']},
#  {'true_id': '593a85ba',
#   'retrieved_ids': ['593a85ba',
#    'c6db65aa',
#    '09081824',
#    'aa187680',
#    '27bdbc3f']},
#  {'true_id': '593a85ba',
#   'retrieved_ids': ['593a85ba',
#    'c6db65aa',
#    '7d217da3',
#    '1ea7680e',
#    'bb1ba786']},
#  {'true_id': '593a85ba',
#   'retrieved_ids': ['593a85ba',
#    'c6db65aa',
#    'bba0da04',
#    'b9b3ef9f',
#    'a2120335']},
#  {'true_id': '593a85ba',
#   'retrieved_ids': ['c6db65aa',
#    '593a85ba',
#    '4eefdd01',
#    'e866156b',
#    'aa187680']},
#  {'true_id': '593a85ba',
#   'retrieved_ids': ['88bf31a0',
#    'c1a95536',
#    '68815ec2',
#    '74c361fe',
#    '4fd37712']},
#  {'true_id': '50bd1a71',
#   'retrieved_ids': ['50bd1a71',
#    'a146e3ee',
#    'b000e899',
#    '72229da5',
#    'e866156b']},
#  {'true_id': '50bd1a71',
#   'retrieved_ids': ['954044d1',
#    'bba0da04',
#    '2b7a8512',
#    '7f845a1c',
#    '0a059700']},
#  {'true_id': '50bd1a71',
#   'retrieved_ids': ['b000e899',
#    '50bd1a71',
#    '16370470',
#    'f409f751',
#    '7d067f5c']},
#  {'true_id': '50bd1a71',
#   'retrieved_ids': ['16370470',
#    'fd714677',
#    'd21bff1d',
#    'c2ec9047',
#    'f409f751']},
#  {'true_id': '50bd1a71',
#   'retrieved_ids': ['a146e3ee',
#    '50bd1a71',
#    'f409f751',
#    '2d653208',
#    'e866156b']},
#  {'true_id': 'f409f751',
#   'retrieved_ids': ['f409f751',
#    'bba0da04',
#    '0a059700',
#    'a2120335',
#    '16c16ff9']},
#  {'true_id': 'f409f751',
#   'retrieved_ids': ['e866156b',
#    '09081824',
#    '22a2b9f2',
#    '947213b1',
#    '27bdbc3f']},
#  {'true_id': 'f409f751',
#   'retrieved_ids': ['f409f751',
#    '50bd1a71',
#    'b000e899',
#    'a146e3ee',
#    '16370470']},
#  {'true_id': 'f409f751',
#   'retrieved_ids': ['b000e899',
#    'f409f751',
#    'a2120335',
#    'a146e3ee',
#    '16c16ff9']},
#  {'true_id': 'f409f751',
#   'retrieved_ids': ['f409f751',
#    '7f845a1c',
#    '50bd1a71',
#    'e866156b',
#    '1e50eab7']},
#  {'true_id': '7d217da3',
#   'retrieved_ids': ['7d217da3',
#    'cd0f9300',
#    '4df80c55',
#    '09081824',
#    '7f845a1c']},
#  {'true_id': '7d217da3',
#   'retrieved_ids': ['e866156b',
#    '7d217da3',
#    'fb930700',
#    'd407d65b',
#    '7d067f5c']},
#  {'true_id': '7d217da3',
#   'retrieved_ids': ['4eefdd01',
#    'e866156b',
#    'd407d65b',
#    'fb930700',
#    '7d067f5c']},
#  {'true_id': '7d217da3',
#   'retrieved_ids': ['fbd3d2bb',
#    'e866156b',
#    '7d067f5c',
#    '7f845a1c',
#    'fb930700']},
#  {'true_id': '7d217da3',
#   'retrieved_ids': ['7d067f5c',
#    '7f845a1c',
#    'e866156b',
#    'd21bff1d',
#    '7d217da3']},
#  {'true_id': '09081824',
#   'retrieved_ids': ['09081824',
#    'bba0da04',
#    'a2120335',
#    'cd0f9300',
#    '68815ec2']},
#  {'true_id': '09081824',
#   'retrieved_ids': ['7d217da3',
#    '7f845a1c',
#    '09081824',
#    '4df80c55',
#    'cd0f9300']},
#  {'true_id': '09081824',
#   'retrieved_ids': ['09081824',
#    '27bdbc3f',
#    '7d217da3',
#    '6497b659',
#    'cd0f9300']},
#  {'true_id': '09081824',
#   'retrieved_ids': ['09081824',
#    'e866156b',
#    'fb930700',
#    'd407d65b',
#    '32e8450c']},
#  {'true_id': '09081824',
#   'retrieved_ids': ['09081824',
#    '27bdbc3f',
#    'cd0f9300',
#    'a02f2039',
#    'fbd3d2bb']},
#  {'true_id': '4df80c55',
#   'retrieved_ids': ['7d067f5c',
#    'fbd3d2bb',
#    '7f845a1c',
#    'c8ad08b3',
#    'f476a606']},
#  {'true_id': '4df80c55',
#   'retrieved_ids': ['4df80c55',
#    'cd0f9300',
#    '7f845a1c',
#    '3b711e73',
#    '7d067f5c']},
#  {'true_id': '4df80c55',
#   'retrieved_ids': ['2d653208',
#    '7f845a1c',
#    'cd0f9300',
#    'd407d65b',
#    'e866156b']},
#  {'true_id': '4df80c55',
#   'retrieved_ids': ['fbd3d2bb',
#    '7d067f5c',
#    '2d653208',
#    '7f845a1c',
#    'f476a606']},
#  {'true_id': '4df80c55',
#   'retrieved_ids': ['7d217da3',
#    '7f845a1c',
#    'cd0f9300',
#    '2d653208',
#    '7d067f5c']},
#  {'true_id': '3aee7261',
#   'retrieved_ids': ['3aee7261',
#    'e866156b',
#    'c6db65aa',
#    'fb930700',
#    '9c66759f']},
#  {'true_id': '3aee7261',
#   'retrieved_ids': ['3aee7261',
#    '9c66759f',
#    'a1e59afc',
#    'e866156b',
#    'fb930700']},
#  {'true_id': '3aee7261',
#   'retrieved_ids': ['3aee7261',
#    'fac138a7',
#    '4292531b',
#    '0728ca67',
#    'a820b9b3']},
#  {'true_id': '3aee7261',
#   'retrieved_ids': ['3aee7261',
#    'fb930700',
#    'e866156b',
#    '9c66759f',
#    'c6db65aa']},
#  {'true_id': '3aee7261',
#   'retrieved_ids': ['3aee7261',
#    '316df755',
#    'f3aa9252',
#    'c9375c56',
#    'c6db65aa']},
#  {'true_id': '6497b659',
#   'retrieved_ids': ['6497b659',
#    '86d11cc0',
#    'b000e899',
#    '316df755',
#    'e866156b']},
#  {'true_id': '6497b659',
#   'retrieved_ids': ['6497b659',
#    '0282578d',
#    '9523c813',
#    'd407d65b',
#    '86d11cc0']},
#  {'true_id': '6497b659',
#   'retrieved_ids': ['6497b659',
#    'c9375c56',
#    'd407d65b',
#    'a4abe7a5',
#    '29f84a82']},
#  {'true_id': '6497b659',
#   'retrieved_ids': ['6497b659',
#    '4eefdd01',
#    '86d11cc0',
#    'b000e899',
#    'e866156b']},
#  {'true_id': '6497b659',
#   'retrieved_ids': ['27bdbc3f',
#    '09081824',
#    '6497b659',
#    'e866156b',
#    'aa187680']},
#  {'true_id': 'a02f2039',
#   'retrieved_ids': ['a02f2039',
#    '09081824',
#    'f3aa9252',
#    'cd0f9300',
#    '27bdbc3f']},
#  {'true_id': 'a02f2039',
#   'retrieved_ids': ['a02f2039',
#    '88bf31a0',
#    'aa187680',
#    'cfe07c9d',
#    '23524e6d']},
#  {'true_id': 'a02f2039',
#   'retrieved_ids': ['a02f2039',
#    '27bdbc3f',
#    '09081824',
#    'b11b8c15',
#    '3916f4a9']},
#  {'true_id': 'a02f2039',
#   'retrieved_ids': ['a02f2039',
#    '7f845a1c',
#    '09081824',
#    'e3106e07',
#    'e866156b']},
#  {'true_id': 'a02f2039',
#   'retrieved_ids': ['a02f2039',
#    '09081824',
#    'cd0f9300',
#    'e3106e07',
#    '27bdbc3f']},
#  {'true_id': 'c6db65aa', 'retrieved_ids': []},
#  {'true_id': 'c6db65aa', 'retrieved_ids': []},
#  {'true_id': 'c6db65aa', 'retrieved_ids': []},
#  {'true_id': 'c6db65aa', 'retrieved_ids': []},
#  {'true_id': 'c6db65aa', 'retrieved_ids': []},
#  {'true_id': 'f476a606',
#   'retrieved_ids': ['f476a606',
#    '7d067f5c',
#    '7f845a1c',
#    'fbd3d2bb',
#    '58c9f99f']},
#  {'true_id': 'f476a606',
#   'retrieved_ids': ['f476a606',
#    '7d067f5c',
#    '0b014d0c',
#    'fbd3d2bb',
#    '2d653208']},
#  {'true_id': 'f476a606',
#   'retrieved_ids': ['e3106e07',
#    '7d067f5c',
#    'f476a606',
#    'fbd3d2bb',
#    'd21bff1d']},
#  {'true_id': 'f476a606',
#   'retrieved_ids': ['f476a606',
#    '0b014d0c',
#    '7d067f5c',
#    'fbd3d2bb',
#    '2d653208']},
#  {'true_id': 'f476a606',
#   'retrieved_ids': ['0b014d0c',
#    '2d653208',
#    '7d067f5c',
#    'f476a606',
#    'fbd3d2bb']},
#  {'true_id': 'e41b100c',
#   'retrieved_ids': ['316df755',
#    '3916f4a9',
#    'e866156b',
#    'd407d65b',
#    '16370470']},
#  {'true_id': 'e41b100c',
#   'retrieved_ids': ['7f845a1c',
#    'e41b100c',
#    'bba0da04',
#    '7d067f5c',
#    'fbd3d2bb']},
#  {'true_id': 'e41b100c',
#   'retrieved_ids': ['a02f2039',
#    '27bdbc3f',
#    '09081824',
#    'a85a6a91',
#    '773587dd']},
#  {'true_id': 'e41b100c',
#   'retrieved_ids': ['09081824',
#    '27bdbc3f',
#    'fbd3d2bb',
#    'e866156b',
#    'fb930700']},
#  {'true_id': 'e41b100c',
#   'retrieved_ids': ['27bdbc3f',
#    '09081824',
#    'cd0f9300',
#    '7f845a1c',
#    'a02f2039']},
#  {'true_id': 'cd0f9300',
#   'retrieved_ids': ['cd0f9300',
#    '7d067f5c',
#    '2d653208',
#    'fbd3d2bb',
#    '4df80c55']},
#  {'true_id': 'cd0f9300',
#   'retrieved_ids': ['cd0f9300',
#    '4df80c55',
#    '09081824',
#    'e41b100c',
#    '7f845a1c']},
#  {'true_id': 'cd0f9300',
#   'retrieved_ids': ['7d217da3',
#    '7d067f5c',
#    'cd0f9300',
#    '2d653208',
#    'fbd3d2bb']},
#  {'true_id': 'cd0f9300',
#   'retrieved_ids': ['7d067f5c',
#    '7d217da3',
#    'cd0f9300',
#    'fbd3d2bb',
#    '2d653208']},
#  {'true_id': 'cd0f9300',
#   'retrieved_ids': ['25daead9',
#    '8b14286c',
#    '94524a9d',
#    '1f519b1a',
#    '33db7dc7']},
#  {'true_id': '7f845a1c',
#   'retrieved_ids': ['7d217da3',
#    '7f845a1c',
#    '7d067f5c',
#    'f0d552a7',
#    'fbd3d2bb']},
#  {'true_id': '7f845a1c',
#   'retrieved_ids': ['02007b7c',
#    'bba0da04',
#    '9211bbd6',
#    'fd714677',
#    '23524e6d']},
#  {'true_id': '7f845a1c',
#   'retrieved_ids': ['7d067f5c',
#    'fbd3d2bb',
#    '2d653208',
#    '4df80c55',
#    'e41b100c']},
#  {'true_id': '7f845a1c',
#   'retrieved_ids': ['7d217da3',
#    '2d653208',
#    '7f845a1c',
#    '7d067f5c',
#    'fbd3d2bb']},
#  {'true_id': '7f845a1c',
#   'retrieved_ids': ['2d653208',
#    '36e54439',
#    '96606db2',
#    '1ea7680e',
#    '7d067f5c']},
#  {'true_id': '36e54439',
#   'retrieved_ids': ['36e54439',
#    '7d067f5c',
#    'fbd3d2bb',
#    '2d653208',
#    '96606db2']},
#  {'true_id': '36e54439',
#   'retrieved_ids': ['36e54439',
#    '96606db2',
#    '2d653208',
#    '1ea7680e',
#    '7d067f5c']},
#  {'true_id': '36e54439',
#   'retrieved_ids': ['36e54439',
#    '96606db2',
#    '2d653208',
#    '7d067f5c',
#    '1ea7680e']},
#  {'true_id': '36e54439',
#   'retrieved_ids': ['36e54439',
#    '2d653208',
#    '96606db2',
#    '7d067f5c',
#    '1ea7680e']},
#  {'true_id': '36e54439',
#   'retrieved_ids': ['36e54439',
#    '96606db2',
#    '2d653208',
#    '1ea7680e',
#    '7d067f5c']},
#  {'true_id': '32e8450c',
#   'retrieved_ids': ['32e8450c',
#    '0282578d',
#    'e866156b',
#    'a1e59afc',
#    '2d653208']},
#  {'true_id': '32e8450c',
#   'retrieved_ids': ['32e8450c',
#    '7d067f5c',
#    'e866156b',
#    'c91ad8f2',
#    '09081824']},
#  {'true_id': '32e8450c',
#   'retrieved_ids': ['32e8450c',
#    '7f845a1c',
#    '2d653208',
#    'e866156b',
#    '6497b659']},
#  {'true_id': '32e8450c',
#   'retrieved_ids': ['fb930700',
#    'e866156b',
#    '32e8450c',
#    'fbd3d2bb',
#    'd407d65b']},
#  {'true_id': '32e8450c',
#   'retrieved_ids': ['32e8450c',
#    'a2120335',
#    'fb930700',
#    'f3f13def',
# ...
#    'c8ad08b3',
#    '74c361fe',
#    '4fd37712']},
#  {'true_id': '4bd23594',
#   'retrieved_ids': ['a1fc1a14',
#    'a2120335',
#    '002d4943',
#    '0a059700',
#    '16c16ff9']},
#  {'true_id': '4bd23594',
#   'retrieved_ids': ['4bd23594',
#    '009ac612',
#    'a2120335',
#    '68815ec2',
#    '4fd37712']},
#  {'true_id': 'b0d48cd7',
#   'retrieved_ids': ['b0d48cd7',
#    '5b55273c',
#    '934facf8',
#    '04656af5',
#    '1023ee65']},
#  {'true_id': 'b0d48cd7',
#   'retrieved_ids': ['b000e899',
#    '16370470',
#    '543ff080',
#    '54c6db2f',
#    'b0d48cd7']},
#  {'true_id': 'b0d48cd7',
#   'retrieved_ids': ['bba0da04',
#    'ffbf3311',
#    '3916f4a9',
#    '0282578d',
#    'c91ad8f2']},
#  {'true_id': 'b0d48cd7',
#   'retrieved_ids': ['b0d48cd7',
#    'f3f13def',
#    'c1a95536',
#    'a1fc1a14',
#    '74c361fe']},
#  {'true_id': 'b0d48cd7',
#   'retrieved_ids': ['b9b3ef9f',
#    '22a2b9f2',
#    '16c16ff9',
#    '47972cb1',
#    '690ba010']},
#  {'true_id': '70a37f2c',
#   'retrieved_ids': ['f3f13def',
#    'a2120335',
#    '74c361fe',
#    'c91ad8f2',
#    'c65d8fd9']},
#  {'true_id': '70a37f2c',
#   'retrieved_ids': ['f3f13def',
#    '70a37f2c',
#    'c65d8fd9',
#    '74c361fe',
#    'a2120335']},
#  {'true_id': '70a37f2c',
#   'retrieved_ids': ['ffbf3311',
#    '20c604dd',
#    '18c5bafe',
#    'b087fa95',
#    '3916f4a9']},
#  {'true_id': '70a37f2c',
#   'retrieved_ids': ['70a37f2c',
#    '3184bd8b',
#    'b000e899',
#    'a2120335',
#    'd407d65b']},
#  {'true_id': '70a37f2c',
#   'retrieved_ids': ['202af70b',
#    '44b14808',
#    '74c361fe',
#    '0513ab8a',
#    'f7252f17']},
#  {'true_id': '8ab78bee',
#   'retrieved_ids': ['bbf094b3',
#    'b087fa95',
#    '8b14286c',
#    '676e1b76',
#    '2aadd232']},
#  {'true_id': '8ab78bee',
#   'retrieved_ids': ['ffbf3311',
#    '3916f4a9',
#    '351a078a',
#    'e265ee5a',
#    'a2120335']},
#  {'true_id': '8ab78bee',
#   'retrieved_ids': ['b6fdd91d',
#    '04656af5',
#    '5a275db7',
#    '155aa868',
#    '690ba010']},
#  {'true_id': '8ab78bee',
#   'retrieved_ids': ['b6fdd91d',
#    '04656af5',
#    '74c361fe',
#    '0516ccbe',
#    '06876291']},
#  {'true_id': '8ab78bee',
#   'retrieved_ids': ['b6fdd91d',
#    '5a275db7',
#    '04656af5',
#    'f7252f17',
#    'aa244fa0']},
#  {'true_id': '54c6db2f',
#   'retrieved_ids': ['947213b1',
#    'bba0da04',
#    'e866156b',
#    '22a2b9f2',
#    'a2120335']},
#  {'true_id': '54c6db2f',
#   'retrieved_ids': ['54c6db2f',
#    'e866156b',
#    'fb930700',
#    '09081824',
#    'fbd3d2bb']},
#  {'true_id': '54c6db2f',
#   'retrieved_ids': ['e866156b',
#    'f09ea61e',
#    '0282578d',
#    'a1e59afc',
#    '2d653208']},
#  {'true_id': '54c6db2f',
#   'retrieved_ids': ['e866156b',
#    'fbd3d2bb',
#    'f09ea61e',
#    '2d653208',
#    '6497b659']},
#  {'true_id': '54c6db2f',
#   'retrieved_ids': ['54c6db2f',
#    'e866156b',
#    '09081824',
#    'f09ea61e',
#    '16370470']},
#  {'true_id': 'c5b998f3',
#   'retrieved_ids': ['c5b998f3',
#    'bba0da04',
#    'de426d2f',
#    '0a0cc4c3',
#    '33db7dc7']},
#  {'true_id': 'c5b998f3',
#   'retrieved_ids': ['c5b998f3',
#    'de426d2f',
#    'd6a5b80e',
#    'f19be91b',
#    '0d1e02d5']},
#  {'true_id': 'c5b998f3',
#   'retrieved_ids': ['3ef0bb96',
#    '0513ab8a',
#    '4cf83cc2',
#    'c5b998f3',
#    'a76e1f4d']},
#  {'true_id': 'c5b998f3',
#   'retrieved_ids': ['c5b998f3',
#    'ffbf3311',
#    '0a059700',
#    '3916f4a9',
#    '66e117dd']},
#  {'true_id': 'c5b998f3',
#   'retrieved_ids': ['c5b998f3',
#    'de426d2f',
#    'cb912983',
#    'bba0da04',
#    '0a059700']},
#  {'true_id': 'eec29536',
#   'retrieved_ids': ['eec29536',
#    'bba0da04',
#    'f19be91b',
#    '0a059700',
#    '3184bd8b']},
#  {'true_id': 'eec29536',
#   'retrieved_ids': ['bba0da04',
#    'eec29536',
#    '2cb48591',
#    '3184bd8b',
#    'f19be91b']},
#  {'true_id': 'eec29536',
#   'retrieved_ids': ['eec29536',
#    'f19be91b',
#    '3184bd8b',
#    '2cb48591',
#    '0a059700']},
#  {'true_id': 'eec29536',
#   'retrieved_ids': ['0a059700',
#    'bba0da04',
#    'a2120335',
#    '009ac612',
#    '4fd37712']},
#  {'true_id': 'eec29536',
#   'retrieved_ids': ['0a059700',
#    'c65d8fd9',
#    'f7252f17',
#    'bba0da04',
#    'a2120335']},
#  {'true_id': '727e5a69',
#   'retrieved_ids': ['727e5a69',
#    '6497b659',
#    '09081824',
#    '593a85ba',
#    '27bdbc3f']},
#  {'true_id': '727e5a69',
#   'retrieved_ids': ['6497b659',
#    '727e5a69',
#    '09081824',
#    '593a85ba',
#    'aa187680']},
#  {'true_id': '727e5a69',
#   'retrieved_ids': ['09081824',
#    '7d067f5c',
#    '27bdbc3f',
#    '0282578d',
#    'aa187680']},
#  {'true_id': '727e5a69',
#   'retrieved_ids': ['09081824',
#    '32e8450c',
#    '16370470',
#    '27bdbc3f',
#    '6497b659']},
#  {'true_id': '727e5a69',
#   'retrieved_ids': ['aa187680',
#    '6afb7b55',
#    'e866156b',
#    'fbd3d2bb',
#    'd407d65b']},
#  {'true_id': 'da899638',
#   'retrieved_ids': ['ffbf3311',
#    '66e117dd',
#    '3916f4a9',
#    '207be93b',
#    'c65d8fd9']},
#  {'true_id': 'da899638',
#   'retrieved_ids': ['da899638',
#    'b9b3ef9f',
#    '954044d1',
#    '16c16ff9',
#    '0a059700']},
#  {'true_id': 'da899638',
#   'retrieved_ids': ['04656af5',
#    'c489266b',
#    'b6fdd91d',
#    '155aa868',
#    '1023ee65']},
#  {'true_id': 'da899638',
#   'retrieved_ids': ['bba0da04',
#    'a2120335',
#    '0a059700',
#    'f7252f17',
#    '009ac612']},
#  {'true_id': 'da899638',
#   'retrieved_ids': ['b6fdd91d',
#    '155aa868',
#    '690ba010',
#    '1023ee65',
#    '315ac3cc']},
#  {'true_id': 'dde58c8f',
#   'retrieved_ids': ['dde58c8f',
#    'f7252f17',
#    'b6fdd91d',
#    '04656af5',
#    '0516ccbe']},
#  {'true_id': 'dde58c8f',
#   'retrieved_ids': ['dde58c8f',
#    '04656af5',
#    '9afa1f74',
#    'f7252f17',
#    '1023ee65']},
#  {'true_id': 'dde58c8f',
#   'retrieved_ids': ['dde58c8f',
#    '16c16ff9',
#    'f7252f17',
#    '04656af5',
#    '0a059700']},
#  {'true_id': 'dde58c8f',
#   'retrieved_ids': ['dde58c8f',
#    'bba0da04',
#    '16c16ff9',
#    'a2120335',
#    'f3f13def']},
#  {'true_id': 'dde58c8f',
#   'retrieved_ids': ['dde58c8f',
#    '04656af5',
#    'b6fdd91d',
#    'ebd63566',
#    '155aa868']},
#  {'true_id': '207be93b',
#   'retrieved_ids': ['207be93b',
#    'ffbf3311',
#    '3916f4a9',
#    '0e424a44',
#    '29865466']},
#  {'true_id': '207be93b',
#   'retrieved_ids': ['207be93b',
#    'ffbf3311',
#    'bba0da04',
#    '0e7dfddc',
#    'b9b3ef9f']},
#  {'true_id': '207be93b',
#   'retrieved_ids': ['207be93b',
#    'a2120335',
#    '68815ec2',
#    'b9b3ef9f',
#    '009ac612']},
#  {'true_id': '207be93b',
#   'retrieved_ids': ['207be93b',
#    'a2120335',
#    '68815ec2',
#    '16c16ff9',
#    'f3f13def']},
#  {'true_id': '207be93b',
#   'retrieved_ids': ['207be93b',
#    'a8657e65',
#    'a1e59afc',
#    'edbae698',
#    '59e86b40']},
#  {'true_id': 'f0617e65',
#   'retrieved_ids': ['5eaf61fe',
#    '67217f4c',
#    '859a97c5',
#    '1cf5be74',
#    '8b14286c']},
#  {'true_id': 'f0617e65',
#   'retrieved_ids': ['ffbf3311',
#    'f0617e65',
#    '3916f4a9',
#    '0513ab8a',
#    '3ef0bb96']},
#  {'true_id': 'f0617e65',
#   'retrieved_ids': ['f0617e65',
#    'ffbf3311',
#    '3916f4a9',
#    '1520b5bc',
#    '7fed7813']},
#  {'true_id': 'f0617e65',
#   'retrieved_ids': ['7fed7813',
#    'f0617e65',
#    '06014eec',
#    '1520b5bc',
#    '59e86b40']},
#  {'true_id': 'f0617e65',
#   'retrieved_ids': ['f0617e65',
#    '1520b5bc',
#    '489c366f',
#    '0174dde5',
#    '3b5b4eb3']},
#  {'true_id': '6290a1a6',
#   'retrieved_ids': ['6290a1a6',
#    'bba0da04',
#    'ffbf3311',
#    'a2120335',
#    '68815ec2']},
#  {'true_id': '6290a1a6',
#   'retrieved_ids': ['6290a1a6',
#    'ffbf3311',
#    '3916f4a9',
#    '5a06248c',
#    'dde58c8f']},
#  {'true_id': '6290a1a6',
#   'retrieved_ids': ['6290a1a6',
#    'ffbf3311',
#    '0282578d',
#    '5a06248c',
#    '3916f4a9']},
#  {'true_id': '6290a1a6',
#   'retrieved_ids': ['6290a1a6',
#    'ffbf3311',
#    'f7252f17',
#    'bba0da04',
#    'a2120335']},
#  {'true_id': '6290a1a6',
#   'retrieved_ids': ['ffbf3311',
#    '6290a1a6',
#    '3916f4a9',
#    '5a06248c',
#    'dde58c8f']},
#  {'true_id': '5a06248c',
#   'retrieved_ids': ['5a06248c',
#    'ffbf3311',
#    'bba0da04',
#    'a2120335',
#    '3916f4a9']},
#  {'true_id': '5a06248c',
#   'retrieved_ids': ['5a06248c',
#    'f7252f17',
#    'ffbf3311',
#    'bba0da04',
#    '0a059700']},
#  {'true_id': '5a06248c',
#   'retrieved_ids': ['5a06248c',
#    'ffbf3311',
#    'a2120335',
#    'c65d8fd9',
#    'f7252f17']},
#  {'true_id': '5a06248c',
#   'retrieved_ids': ['5a06248c',
#    'ffbf3311',
#    '3916f4a9',
#    '954044d1',
#    '138b55c7']},
#  {'true_id': '5a06248c',
#   'retrieved_ids': ['5a06248c',
#    'ffbf3311',
#    '3916f4a9',
#    'bba0da04',
#    'f7252f17']},
#  {'true_id': 'c46a2e9e',
#   'retrieved_ids': ['a820b9b3',
#    'eb56ae98',
#    '52393fb3',
#    '04aa4897',
#    'c02e79ef']},
#  {'true_id': '0513ab8a',
#   'retrieved_ids': ['0513ab8a',
#    'b9b3ef9f',
#    'ffbf3311',
#    'a2120335',
#    '74c361fe']},
#  {'true_id': '0513ab8a',
#   'retrieved_ids': ['ffbf3311',
#    '3916f4a9',
#    '0513ab8a',
#    'b7b9487d',
#    'a9385356']},
#  {'true_id': '0513ab8a',
#   'retrieved_ids': ['ffbf3311',
#    '0513ab8a',
#    '0282578d',
#    '3916f4a9',
#    'a9385356']},
#  {'true_id': '0513ab8a',
#   'retrieved_ids': ['a2120335',
#    'e265ee5a',
#    '74c361fe',
#    'b9b3ef9f',
#    '009ac612']},
#  {'true_id': '0513ab8a',
#   'retrieved_ids': ['a2120335',
#    'a9385356',
#    'ffbf3311',
#    'bba0da04',
#    '0513ab8a']},
#  {'true_id': 'a9385356',
#   'retrieved_ids': ['a9385356',
#    'ffbf3311',
#    '3916f4a9',
#    '6d67fba9',
#    '3c41892d']},
#  {'true_id': 'a9385356',
#   'retrieved_ids': ['a9385356',
#    'ffbf3311',
#    '3916f4a9',
#    '3c41892d',
#    'ddf6c1b3']},
#  {'true_id': 'a9385356',
#   'retrieved_ids': ['a9385356',
#    'ffbf3311',
#    'a2120335',
#    'a2c7b59f',
#    '6d67fba9']},
#  {'true_id': 'a9385356',
#   'retrieved_ids': ['a9385356',
#    'ffbf3311',
#    'f2945cd2',
#    '6d67fba9',
#    '3916f4a9']},
#  {'true_id': 'a9385356',
#   'retrieved_ids': ['ffbf3311',
#    'a9385356',
#    '3916f4a9',
#    '0513ab8a',
#    '16370470']},
#  {'true_id': 'c30468c0',
#   'retrieved_ids': ['c30468c0',
#    'bba0da04',
#    'fd714677',
#    '68815ec2',
#    '207be93b']},
#  {'true_id': 'c30468c0',
#   'retrieved_ids': ['752e8452',
#    '4f8d9174',
#    'c30468c0',
#    'ff352621',
#    'f09ea61e']},
#  {'true_id': 'c30468c0',
#   'retrieved_ids': ['827dd4af',
#    '09081824',
#    'f3aa9252',
#    '5d7588f0',
#    '4df80c55']},
#  {'true_id': 'c30468c0',
#   'retrieved_ids': ['3184bd8b',
#    '68842c02',
#    'b2799574',
#    'e4a7c3b0',
#    '504b8570']},
#  {'true_id': 'c30468c0',
#   'retrieved_ids': ['11a814ea',
#    'a2120335',
#    '0a059700',
#    '1f1ecbb7',
#    'b9b3ef9f']},
#  {'true_id': '305aead7',
#   'retrieved_ids': ['305aead7',
#    'ffbf3311',
#    '3916f4a9',
#    'ddf6c1b3',
#    'f19be91b']},
#  {'true_id': '305aead7',
#   'retrieved_ids': ['ffbf3311',
#    '0513ab8a',
#    '3916f4a9',
#    'bba0da04',
#    '305aead7']},
#  {'true_id': '305aead7',
#   'retrieved_ids': ['7d067f5c',
#    'ff352621',
#    'fbd3d2bb',
#    '2d653208',
#    'f476a606']},
#  {'true_id': '305aead7',
#   'retrieved_ids': ['305aead7',
#    'ffbf3311',
#    'bba0da04',
#    '3916f4a9',
#    'a2120335']},
#  {'true_id': '305aead7',
#   'retrieved_ids': ['ffbf3311',
#    '3916f4a9',
#    'a9385356',
#    '305aead7',
#    '9c85f3aa']},
#  {'true_id': '77410975',
#   'retrieved_ids': ['ffbf3311',
#    '77410975',
#    'bba0da04',
#    'a2120335',
#    '3916f4a9']},
#  {'true_id': '77410975',
#   'retrieved_ids': ['77410975',
#    '4cf83cc2',
#    'b0d48cd7',
#    'a9385356',
#    'ffbf3311']},
#  {'true_id': '77410975',
#   'retrieved_ids': ['77410975',
#    'ffbf3311',
#    '3916f4a9',
#    '5fa98bd0',
#    '70ac8e80']},
#  {'true_id': '77410975',
#   'retrieved_ids': ['77410975',
#    '68815ec2',
#    '0a059700',
#    'c65d8fd9',
#    '16c16ff9']},
#  {'true_id': '77410975',
#   'retrieved_ids': ['77410975',
#    'ffbf3311',
#    '70ac8e80',
#    '3916f4a9',
#    '009ac612']},
#  {'true_id': '0952abde',
#   'retrieved_ids': ['690ba010',
#    '155aa868',
#    'e78cf960',
#    '1023ee65',
#    '6d67fba9']},
#  {'true_id': '0952abde',
#   'retrieved_ids': ['c8ad08b3',
#    'a2120335',
#    'f3f13def',
#    '4fd37712',
#    '0a059700']},
#  {'true_id': '0952abde',
#   'retrieved_ids': ['0952abde',
#    'f7252f17',
#    '4fd37712',
#    'ffbf3311',
#    'c65d8fd9']},
#  {'true_id': '0952abde',
#   'retrieved_ids': ['0952abde',
#    'ffbf3311',
#    'a9385356',
#    '33db7dc7',
#    'ddc3c75b']},
#  {'true_id': '0952abde',
#   'retrieved_ids': ['ffbf3311',
#    '0952abde',
#    '3916f4a9',
#    '002d4943',
#    'a1fc1a14']},
#  {'true_id': '7c4326eb',
#   'retrieved_ids': ['7c4326eb',
#    'ffbf3311',
#    '3916f4a9',
#    'a9385356',
#    'a2120335']},
#  {'true_id': '7c4326eb',
#   'retrieved_ids': ['7c4326eb',
#    'ffbf3311',
#    '3916f4a9',
#    '0952abde',
#    'a9385356']},
#  {'true_id': '7c4326eb',
#   'retrieved_ids': ['ffbf3311',
#    '7c4326eb',
#    'a2120335',
#    '009ac612',
#    '0a059700']},
#  {'true_id': '7c4326eb',
#   'retrieved_ids': ['7c4326eb',
#    '0282578d',
#    'a1fc1a14',
#    '4eefdd01',
#    'c5c3beba']},
#  {'true_id': '7c4326eb',
#   'retrieved_ids': ['7c4326eb',
#    'ffbf3311',
#    'f55efcf0',
#    'a2120335',
#    'c65d8fd9']},
#  {'true_id': 'a1fc1a14',
#   'retrieved_ids': ['a1fc1a14',
#    '04656af5',
#    '6d67fba9',
#    'c489266b',
#    '690ba010']},
#  {'true_id': 'a1fc1a14',
#   'retrieved_ids': ['a2120335',
#    '16c16ff9',
#    '0a059700',
#    'b9b3ef9f',
#    'a1fc1a14']},
#  {'true_id': 'a1fc1a14',
#   'retrieved_ids': ['a1fc1a14',
#    'ffbf3311',
#    '002d4943',
#    '6d67fba9',
#    'a9385356']},
#  {'true_id': 'a1fc1a14',
#   'retrieved_ids': ['a1fc1a14',
#    'fd714677',
#    '50c009ef',
#    'd7ad69da',
#    'de06929d']},
#  {'true_id': 'a1fc1a14',
#   'retrieved_ids': ['a1fc1a14',
#    '0282578d',
#    '002d4943',
#    'ffbf3311',
#    '3916f4a9']},
#  {'true_id': '6d67fba9',
#   'retrieved_ids': ['c0a46e5d',
#    '591df4e6',
#    '1520b5bc',
#    'f95304db',
#    '3b5b4eb3']},
#  {'true_id': '6d67fba9',
#   'retrieved_ids': ['6d67fba9',
#    '591df4e6',
#    'ffbf3311',
#    '3916f4a9',
#    'f10b49be']},
#  {'true_id': '6d67fba9',
#   'retrieved_ids': ['6d67fba9',
#    'a7cecdf9',
#    'a1fc1a14',
#    '002d4943',
#    '591df4e6']},
#  {'true_id': '6d67fba9',
#   'retrieved_ids': ['1520b5bc',
#    'c0a46e5d',
#    '3b5b4eb3',
#    '5cc0e4d9',
#    'ddc3c75b']},
#  {'true_id': '6d67fba9',
#   'retrieved_ids': ['6d67fba9',
#    '591df4e6',
#    'ffbf3311',
#    'a7cecdf9',
#    'a9385356']},
#  {'true_id': '06876291',
#   'retrieved_ids': ['7d067f5c',
#    'fbd3d2bb',
#    '2d653208',
#    'f476a606',
#    'c6db65aa']},
#  {'true_id': '06876291',
#   'retrieved_ids': ['9c66759f',
#    '5a275db7',
#    'a1e59afc',
#    '06876291',
#    'ff352621']},
#  {'true_id': '06876291',
#   'retrieved_ids': ['0002ab8b',
#    '06876291',
#    '71c10610',
#    '63823f21',
#    '74c361fe']},
#  {'true_id': '06876291',
#   'retrieved_ids': ['5a275db7',
#    '752e8452',
#    '06876291',
#    '593a85ba',
#    '7ec0f9b0']},
#  {'true_id': '06876291',
#   'retrieved_ids': ['06876291',
#    'b087fa95',
#    '2fdc5057',
#    '14a876ea',
#    'c599b3a0']},
#  {'true_id': '690ba010',
#   'retrieved_ids': ['690ba010',
#    '155aa868',
#    '1023ee65',
#    'e78cf960',
#    'b6fdd91d']},
#  {'true_id': '690ba010',
#   'retrieved_ids': ['690ba010',
#    '1023ee65',
#    '155aa868',
#    'e78cf960',
#    '14a876ea']},
#  {'true_id': '690ba010',
#   'retrieved_ids': ['690ba010',
#    '155aa868',
#    '1023ee65',
#    'e78cf960',
#    'b6fdd91d']},
#  {'true_id': '690ba010',
#   'retrieved_ids': ['690ba010',
#    'a2120335',
#    '16c16ff9',
#    '74c361fe',
#    'b9b3ef9f']},
#  {'true_id': '690ba010',
#   'retrieved_ids': ['155aa868',
#    '690ba010',
#    '1023ee65',
#    'b6fdd91d',
#    '04656af5']},
#  {'true_id': 'b6fdd91d',
#   'retrieved_ids': ['1023ee65',
#    'b6fdd91d',
#    '04656af5',
#    '690ba010',
#    '155aa868']},
#  {'true_id': 'b6fdd91d',
#   'retrieved_ids': ['a2120335',
#    'f3f13def',
#    'f7252f17',
#    '155aa868',
#    'b6fdd91d']},
#  {'true_id': 'b6fdd91d',
#   'retrieved_ids': ['f3f13def',
#    '74c361fe',
#    'e265ee5a',
#    'a2120335',
#    'f7252f17']},
#  {'true_id': 'b6fdd91d',
#   'retrieved_ids': ['b9b3ef9f',
#    '74c361fe',
#    'a2120335',
#    '5eaf61fe',
#    'f7252f17']},
#  {'true_id': 'b6fdd91d',
#   'retrieved_ids': ['04656af5',
#    'b6fdd91d',
#    'c489266b',
#    '1023ee65',
#    '0174dde5']},
#  {'true_id': '155aa868',
#   'retrieved_ids': ['155aa868',
#    'a2120335',
#    'bba0da04',
#    '1023ee65',
#    'b6fdd91d']},
#  {'true_id': '155aa868',
#   'retrieved_ids': ['155aa868',
#    'c8ad08b3',
#    'f7252f17',
#    'c65d8fd9',
#    '0a059700']},
#  {'true_id': '155aa868',
#   'retrieved_ids': ['155aa868',
#    'b9b3ef9f',
#    'f7252f17',
#    '690ba010',
#    '0a059700']},
#  {'true_id': '155aa868',
#   'retrieved_ids': ['155aa868',
#    '1023ee65',
#    '690ba010',
#    'b6fdd91d',
#    'e78cf960']},
#  {'true_id': '155aa868',
#   'retrieved_ids': ['155aa868',
#    '690ba010',
#    'e78cf960',
#    '1023ee65',
#    'b6fdd91d']},
#  {'true_id': 'e78cf960',
#   'retrieved_ids': ['e78cf960',
#    '1023ee65',
#    '04656af5',
#    '155aa868',
#    'c489266b']},
#  ...]

# %%
for res in minsearch_results[:5]:
    print(f"Id: {res['true_id']} -> Retrieved Ids: {res['retrieved_ids']}")
# Out:
# Id: c02e79ef -> Retrieved Ids: ['c02e79ef', 'a482086d', '7842b56a', '63394d91', '1f6520ca']
# Id: c02e79ef -> Retrieved Ids: ['a482086d', 'c02e79ef', '2f19301f', 'eb56ae98', '63394d91']
# Id: c02e79ef -> Retrieved Ids: ['c02e79ef', '1f6520ca', '04aa4897', '0e424a44', '29865466']
# Id: c02e79ef -> Retrieved Ids: ['c02e79ef', 'a482086d', '2f19301f', '63394d91', '0bbf41ec']
# Id: c02e79ef -> Retrieved Ids: ['c02e79ef', 'bba0da04', '7842b56a', 'a2120335', '009ac612']

# %%
print(f"Hit Rate: {hit_rate(minsearch_results)}")
print(f"MMR: {mmr(minsearch_results)}")
print(f"Recall@3: {recall_at_k(minsearch_results, 3)}")
# Out:
# Hit Rate: 0.8178085152366544
# MMR: 0.6959801167062899
# Recall@3: 0.7661551761400476
